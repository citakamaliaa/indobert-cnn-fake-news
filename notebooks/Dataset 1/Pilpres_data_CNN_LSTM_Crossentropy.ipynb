# %% [markdown]
# ##Install Library and preparing

# %%
# !pip install torch
# !pip install tf
# !pip install -q gdown
# !pip install transformers[torch] accelerate -U
# !pip install accelerate -U
# !pip install datasets
# !pip install gensim
# !pip install evaluate

import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import re
import gc
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report
from collections import Counter
import tensorflow as tf
from gensim.models import Word2Vec
from transformers import AutoTokenizer, AutoModelForSequenceClassification,Trainer, AutoConfig, TrainingArguments, EarlyStoppingCallback
from tensorflow.keras.layers import Input, Embedding, Conv1D, GlobalMaxPooling1D, MaxPooling1D, Dense, Flatten, concatenate, BatchNormalization,LSTM, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import backend as K
from evaluate import load
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import he_normal
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import BorderlineSMOTE,KMeansSMOTE,SVMSMOTE
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Collecting tf
#   Downloading tf-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: cryptography>43 in /usr/local/lib/python3.12/dist-packages (from tf) (43.0.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.67.1 in /usr/local/lib/python3.12/dist-packages (from tf) (1.76.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tf) (1.1.2)
# Requirement already satisfied: protobuf<6.0.0,>=5.28.3 in /usr/local/lib/python3.12/dist-packages (from tf) (5.29.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>43->tf) (2.0.0)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0.0,>=1.67.1->tf) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>43->tf) (2.23)
# Downloading tf-1.1.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: tf
# Successfully installed tf-1.1.0
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (4.67.1)
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.9.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers[torch]) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers[torch]) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (3.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers[torch]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers[torch]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers[torch]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers[torch]) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2->transformers[torch]) (3.0.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.9.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.11.12)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 98.8 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %% [markdown]
# ###Read Dataset and load Word2Vec

# %%
df = pd.read_csv("/content/pilpres_train_balanced_clean.csv")

# %%
df_test1 = pd.read_csv("/content/pilpres_test_clean.csv")
# df_test2 = pd.read_csv("test_data_2.csv")
# df_test3 = pd.read_csv("test_data_3.csv")

# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
gc.collect()
print(gensim.__version__)
# Load Pretrained Word Embeddings (Word2Vec)
# !gdown --id 1QYj5FruufaPq2mZgC6lZlq2Uw2E004Og
# !gdown --id 1F9QsHO7FPIPq3nL_I0zCkZFvq3OVcJrB
# !gdown --id 1VUjxpH10baOw439V-YAAVVbtyI8iLgG5
# Out:
# 4.4.0

# %%
import os
import gdown
import zipfile

'''https://drive.google.com/file/d/1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3/view?usp=sharing'''

file_id = '1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3'

url = f'https://drive.google.com/uc?id={file_id}'
output_zip = 'model_w2v.zip'

if not os.path.exists('idwiki_word2vec_768_new_lower.model'):
    print("Downloading Model...")
    gdown.download(url, output_zip, quiet=False)

    print("Extracting File...")
    with zipfile.ZipFile(output_zip, 'r') as zip_ref:
        zip_ref.extractall('/content/')
    print("Done.")
else:
    print("Model Available")
# Out:
# Downloading Model...
# Downloading...
# From (original): https://drive.google.com/uc?id=1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3
# From (redirected): https://drive.google.com/uc?id=1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3&confirm=t&uuid=443c80e3-2d86-4dd5-b177-a4f9baf581d1
# To: /content/model_w2v.zip
# 100%|██████████| 2.56G/2.56G [00:15<00:00, 164MB/s]
# Extracting File...
# Done.

# %%
word_embeddings = Word2Vec.load('/content/idwiki_word2vec_768_new_lower.model')
#word_embeddings = Word2Vec.load('/content/modelword2vec/idwiki_word2vec_768_new_lower.model')

# %% [markdown]
# ###Split Dataset

# %%
x_train = df['Text']
y_train = df['Label']

# %%
x_test1 = df_test1['Text']
y_test1 = np.array(df_test1['Label'])

# %%
# x_test2 = df_test2['Text']
# y_test2 = np.array(df_test2['Label'])

# %%
# x_test3 = df_test3['Text']
# y_test3 = np.array(df_test3['Label'])

# %% [markdown]
# ###Define Loss Function, Tokenization, Word Embeddings and Oversampling

# %%
# # Define the margin loss function
# def margin_loss(y_true, y_pred):
#     margin = K.constant(0.1)
#     y_true_float = K.cast(y_true, dtype='float32')  # Convert y_true to float32
#     squared_difference_pos = K.square(K.maximum(0.9 - y_pred, 0))
#     squared_difference_neg = K.square(K.maximum(y_pred - 0.1, 0))
#     loss_pos = K.mean(y_true_float * squared_difference_pos)
#     loss_neg = K.mean((1 - y_true_float) * squared_difference_neg)
#     total_loss = loss_pos + lambda_val * loss_neg
#     return total_loss

# %%
# Define the model architectures
#embedding_dim = 300
#max_sequence_length = 100
# lambda_val = 0.7  # Lambda value for margin loss
#num_words = 100000

# %%
# Create word index
word_index = {word: index + 1 for index, word in enumerate(word_embeddings.wv.index_to_key)}

# Create embedding matrix
embedding_dim = word_embeddings.vector_size
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    if word in word_embeddings.wv:
        embedding_vector = word_embeddings.wv[word]
        embedding_matrix[i] = embedding_vector

# %%
# Tokenization
tokenizer = Tokenizer(num_words=len(word_index) + 1, oov_token='<OOV>')
tokenizer.fit_on_texts(x_train.astype(str))

# Convert text to sequences and pad
x_train_sequences = tokenizer.texts_to_sequences(x_train.astype(str))
# Convert all values in x_test1 to string before tokenization
x_test_sequences1 = tokenizer.texts_to_sequences(x_test1.astype(str))

# Determine max sequence length based on your data
max_sequence_length = max(max(len(seq) for seq in x_train_sequences), max(len(seq) for seq in x_test_sequences1))

x_train_padded = pad_sequences(x_train_sequences, maxlen=max_sequence_length, padding='post')
x_test_padded1 = pad_sequences(x_test_sequences1, maxlen=max_sequence_length, padding='post')

# %%
x_train_flat = x_train_padded.reshape(x_train_padded.shape[0], -1)

# %% [markdown]
# ####Oversampling with BorderlineSMOTE

# %%
borderline_smote = BorderlineSMOTE(random_state=42)
x_train_resampled_flat_borderline, y_train_resampled_borderline = borderline_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_borderline = x_train_resampled_flat_borderline.reshape(x_train_resampled_flat_borderline.shape[0], max_sequence_length)

# %% [markdown]
# ####Oversampling with KMeansSMOTE

# %%
kmeans_smote = KMeansSMOTE(random_state=42, cluster_balance_threshold=0.2)
x_train_resampled_flat_kmeans, y_train_resampled_kmeans = kmeans_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_kmeans = x_train_resampled_flat_kmeans.reshape(x_train_resampled_flat_kmeans.shape[0], max_sequence_length)

# %% [markdown]
# ####Oversampling with SVMSMOTE

# %%
svm_smote = SVMSMOTE(random_state=42)
x_train_resampled_flat_svm, y_train_resampled_svm = svm_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_svm = x_train_resampled_flat_svm.reshape(x_train_resampled_flat_svm.shape[0], max_sequence_length)

# %%
torch.cuda.empty_cache()
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
from google.colab import drive
drive.flush_and_unmount()
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %% [markdown]
# ##CNN + LSTM

# %%
# Define the architecture of the hybrid model with he_normal initialization
static_input = Input(shape=(max_sequence_length,))
static_embedding = Embedding(len(word_index) + 1, embedding_dim, input_length=max_sequence_length, trainable=False)(static_input)  # Removed weights parameter

# CNN Layers
static_cnn_output = Conv1D(128, 3, activation='relu', kernel_initializer=he_normal())(static_embedding)  # Use he_normal initialization
static_cnn_output = MaxPooling1D(2)(static_cnn_output)
static_cnn_output = GlobalMaxPooling1D()(static_cnn_output)
static_cnn_output = Dropout(0.5)(static_cnn_output)
batch_norm_layer_cnn = BatchNormalization()(static_cnn_output)

# LSTM Layer
static_lstm_output = LSTM(128, kernel_initializer=he_normal())(static_embedding)  # Use he_normal initialization
static_lstm_output = Dropout(0.5)(static_lstm_output)
batch_norm_layer_lstm = BatchNormalization()(static_lstm_output)

# Concatenate CNN and LSTM outputs
merged_layer = tf.keras.layers.concatenate([batch_norm_layer_cnn, batch_norm_layer_lstm], axis=-1)

# Fully Connected Layers
static_dense_output = Dense(128, activation='relu', kernel_initializer=he_normal())(merged_layer)  # Use he_normal initialization
static_dense_output = Dropout(0.5)(static_dense_output)
output = Dense(1, activation='sigmoid')(static_dense_output)

# Create the hybrid model
hybrid_model = Model(inputs=static_input, outputs=output)
hybrid_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(patience=3, restore_best_weights=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# ###CNN + LSTM BorderlineSMOTE Train and Test

# %%
# Train the CNN + LSTM model
epochs_hybrid = 10
history_hybrid_borderline = hybrid_model.fit(
    x_train_resampled_borderline,
    y_train_resampled_borderline,
    batch_size=32,
    epochs=epochs_hybrid,
    validation_split=0.1,
)
# Out:
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5700 - loss: 0.7921 - val_accuracy: 0.6592 - val_loss: 0.6391
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8651 - loss: 0.3025 - val_accuracy: 0.9666 - val_loss: 0.2896
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9510 - loss: 0.1474 - val_accuracy: 0.9841 - val_loss: 0.0904
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9672 - loss: 0.0973 - val_accuracy: 0.9873 - val_loss: 0.0292
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9717 - loss: 0.0837 - val_accuracy: 0.9920 - val_loss: 0.0155
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9708 - loss: 0.0817 - val_accuracy: 0.9968 - val_loss: 0.0105
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9754 - loss: 0.0677 - val_accuracy: 0.9984 - val_loss: 0.0030
# Epoch 8/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9787 - loss: 0.0581 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 9/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9802 - loss: 0.0606 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 10/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9810 - loss: 0.0496 - val_accuracy: 0.9984 - val_loss: 0.0056

# %%
# Convert the data to numpy arrays
x_train_np = np.array(x_train_resampled_borderline)
y_train_np = np.array(y_train_resampled_borderline)

# %%
from sklearn.model_selection import KFold
# Define the number of folds
num_folds = 10

# Initialize K-Fold cross-validator
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)  # You can set a random seed for reproducibility

# Initialize lists to store cross-validation results
accuracies = []
losses = []

# %%
# Initialize lists to store training and validation accuracies and losses
train_accuracies_hybrid = []
val_accuracies_hybrid = []
train_losses_hybrid = []
val_losses_hybrid = []
classification_reports_hybrid = []
# Iterate over the folds
fold = 0
for train_indices, val_indices in kf.split(x_train_np):
    fold += 1
    print(f"Training fold {fold}/{num_folds}")

    hybrid_model = Model(inputs=static_input, outputs=output)

    hybrid_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # Get the training and validation data for this fold
    x_train_fold = x_train_np[train_indices]
    y_train_fold = y_train_np[train_indices]
    x_val_fold = x_train_np[val_indices]
    y_val_fold = y_train_np[val_indices]

    # Early stopping callback
    early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

    # Train the model for this fold
    history = hybrid_model.fit(
        x_train_fold,
        y_train_fold,
        batch_size=32,
        epochs=epochs_hybrid,  # Make sure you define epochs_hybrid
        validation_data=(x_val_fold, y_val_fold),
        callbacks=[early_stopping],
    )

    # Evaluate the model on this fold for training and validation
    train_loss_hybrid, train_accuracy_hybrid = hybrid_model.evaluate(x_train_fold, y_train_fold)
    val_loss_hybrid, val_accuracy_hybrid = hybrid_model.evaluate(x_val_fold, y_val_fold)

    print(f"Fold {fold} - Training Loss: {train_loss_hybrid}, Training Accuracy: {train_accuracy_hybrid}")
    print(f"Fold {fold} - Validation Loss: {val_loss_hybrid}, Validation Accuracy: {val_accuracy_hybrid}")

    # Store the results for this fold
    train_accuracies_hybrid.append(train_accuracy_hybrid)
    val_accuracies_hybrid.append(val_accuracy_hybrid)
    train_losses_hybrid.append(train_loss_hybrid)
    val_losses_hybrid.append(val_loss_hybrid)

    # Evaluate the model
    y_pred = (hybrid_model.predict(x_val_fold) > 0.5).astype("int32").flatten()

    # Generate and store the classification report
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports_hybrid.append(report)

    # Print the classification report for this fold
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)
# Out:
# Training fold 1/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9823 - loss: 0.0484 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9751 - loss: 0.0851 - val_accuracy: 0.9984 - val_loss: 0.0050
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9742 - loss: 0.0743 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9859 - loss: 0.0385 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9878 - loss: 0.0342 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9850 - loss: 0.0435 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9866 - loss: 0.0452 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 8/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9853 - loss: 0.0433 - val_accuracy: 0.9984 - val_loss: 0.0021
# Epoch 9/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9876 - loss: 0.0337 - val_accuracy: 1.0000 - val_loss: 0.0016
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.0031
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016
# Fold 1 - Training Loss: 0.0028778871055692434, Training Accuracy: 0.9991143941879272
# Fold 1 - Validation Loss: 0.0013419846072793007, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       327
#            1       1.00      1.00      1.00       301
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 2/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9858 - loss: 0.0449 - val_accuracy: 0.9984 - val_loss: 0.0093
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9922 - loss: 0.0285 - val_accuracy: 0.9984 - val_loss: 0.0088
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9857 - loss: 0.0515 - val_accuracy: 0.9968 - val_loss: 0.0124
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9851 - loss: 0.0477 - val_accuracy: 0.9968 - val_loss: 0.0152
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9890 - loss: 0.0401 - val_accuracy: 0.9968 - val_loss: 0.0121
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9988 - loss: 0.0040
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0089
# Fold 2 - Training Loss: 0.002539620967581868, Training Accuracy: 0.9992915391921997
# Fold 2 - Validation Loss: 0.008763996884226799, Validation Accuracy: 0.9984076619148254
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       300
#            1       1.00      1.00      1.00       328
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 3/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9879 - loss: 0.0392 - val_accuracy: 0.9968 - val_loss: 0.0051
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9859 - loss: 0.0425 - val_accuracy: 0.9968 - val_loss: 0.0101
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9914 - loss: 0.0278 - val_accuracy: 0.9968 - val_loss: 0.0117
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9896 - loss: 0.0378 - val_accuracy: 0.9952 - val_loss: 0.0112
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9989 - loss: 0.0025
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9974 - loss: 0.0061
# Fold 3 - Training Loss: 0.001962715294212103, Training Accuracy: 0.9991143941879272
# Fold 3 - Validation Loss: 0.005106446798890829, Validation Accuracy: 0.9968152642250061
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       316
#            1       0.99      1.00      1.00       312
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 4/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9864 - loss: 0.0363 - val_accuracy: 0.9984 - val_loss: 0.0021
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9891 - loss: 0.0403 - val_accuracy: 0.9984 - val_loss: 0.0024
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9926 - loss: 0.0229 - val_accuracy: 0.9984 - val_loss: 0.0021
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9904 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9924 - loss: 0.0219 - val_accuracy: 0.9984 - val_loss: 0.0020
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9855 - loss: 0.0364 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9887 - loss: 0.0325 - val_accuracy: 0.9952 - val_loss: 0.0066
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9993 - loss: 0.0016
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0013
# Fold 4 - Training Loss: 0.0011993428925052285, Training Accuracy: 0.9994686245918274
# Fold 4 - Validation Loss: 0.0011424653930589557, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       323
#            1       1.00      1.00      1.00       305
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 5/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9868 - loss: 0.0359 - val_accuracy: 0.9984 - val_loss: 0.0018
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9869 - loss: 0.0338 - val_accuracy: 0.9984 - val_loss: 0.0039
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9912 - loss: 0.0248 - val_accuracy: 0.9984 - val_loss: 0.0043
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9929 - loss: 0.0206 - val_accuracy: 0.9984 - val_loss: 0.0031
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9996 - loss: 0.0017
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0017
# Fold 5 - Training Loss: 0.0011461322428658605, Training Accuracy: 0.9998229146003723
# Fold 5 - Validation Loss: 0.0018090222729369998, Validation Accuracy: 0.9984050989151001
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       292
#            1       1.00      1.00      1.00       335
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 6/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9887 - loss: 0.0289 - val_accuracy: 1.0000 - val_loss: 4.4741e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9893 - loss: 0.0370 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9890 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 7.1275e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9931 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 1.3732e-04
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9930 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 3.1542e-04
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9918 - loss: 0.0233 - val_accuracy: 0.9984 - val_loss: 0.0029
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9884 - loss: 0.0373 - val_accuracy: 1.0000 - val_loss: 0.0011
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9994 - loss: 0.0012
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.3305e-04
# Fold 6 - Training Loss: 0.0008545175078324974, Training Accuracy: 0.9996458292007446
# Fold 6 - Validation Loss: 0.00013731737271882594, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       311
#            1       1.00      1.00      1.00       316
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 7/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9931 - loss: 0.0211 - val_accuracy: 0.9984 - val_loss: 0.0036
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9952 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9908 - loss: 0.0294 - val_accuracy: 0.9984 - val_loss: 0.0030
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9889 - loss: 0.0281 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9845 - loss: 0.0396 - val_accuracy: 0.9984 - val_loss: 0.0031
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9988 - loss: 0.0028
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016
# Fold 7 - Training Loss: 0.002256388310343027, Training Accuracy: 0.9991145730018616
# Fold 7 - Validation Loss: 0.0013233019271865487, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       308
#            1       1.00      1.00      1.00       319
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 8/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9907 - loss: 0.0288 - val_accuracy: 1.0000 - val_loss: 2.0806e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9840 - loss: 0.0419 - val_accuracy: 0.9984 - val_loss: 0.0016
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9897 - loss: 0.0268 - val_accuracy: 0.9984 - val_loss: 0.0014
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9898 - loss: 0.0262 - val_accuracy: 1.0000 - val_loss: 0.0010
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9992 - loss: 0.0012
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.6885e-04
# Fold 8 - Training Loss: 0.0009678300702944398, Training Accuracy: 0.9994687438011169
# Fold 8 - Validation Loss: 0.00020805624080821872, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       327
#            1       1.00      1.00      1.00       300
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 9/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9889 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 2.6858e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9905 - loss: 0.0292 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9913 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 4.4431e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9909 - loss: 0.0262 - val_accuracy: 1.0000 - val_loss: 3.6317e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9984 - loss: 0.0026
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.1809e-04
# Fold 9 - Training Loss: 0.001790267531760037, Training Accuracy: 0.9989374876022339
# Fold 9 - Validation Loss: 0.0002685763465706259, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       322
#            1       1.00      1.00      1.00       305
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 10/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9921 - loss: 0.0202 - val_accuracy: 0.9984 - val_loss: 0.0025
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9916 - loss: 0.0253 - val_accuracy: 0.9984 - val_loss: 0.0018
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9932 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 9.6190e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9870 - loss: 0.0328 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9926 - loss: 0.0213 - val_accuracy: 0.9984 - val_loss: 0.0104
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9938 - loss: 0.0191 - val_accuracy: 0.9984 - val_loss: 0.0094
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.3352e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0022
# Fold 10 - Training Loss: 0.00029666494810953736, Training Accuracy: 1.0
# Fold 10 - Validation Loss: 0.0009618960320949554, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       311
#            1       1.00      1.00      1.00       316
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------

# %%
# Calculate and print the mean and standard deviation of training accuracy and loss across folds
mean_train_accuracy = sum(train_accuracies_hybrid) / num_folds
std_train_accuracy = (sum([(acc - mean_train_accuracy) ** 2 for acc in train_accuracies_hybrid]) / num_folds) ** 0.5
mean_train_loss = sum(train_losses_hybrid) / num_folds
std_train_loss = (sum([(loss - mean_train_loss) ** 2 for loss in train_losses_hybrid]) / num_folds) ** 0.5
print(f"Mean Training Accuracy: {mean_train_accuracy}, Std Training Accuracy: {std_train_accuracy}")
print(f"Mean Training Loss: {mean_train_loss}, Std Training Loss: {std_train_loss}")

# Calculate and print the mean and standard deviation of validation accuracy and loss across folds
mean_val_accuracy = sum(val_accuracies_hybrid) / num_folds
std_val_accuracy = (sum([(acc - mean_val_accuracy) ** 2 for acc in val_accuracies_hybrid]) / num_folds) ** 0.5
mean_val_loss = sum(val_losses_hybrid) / num_folds
std_val_loss = (sum([(loss - mean_val_loss) ** 2 for loss in val_losses_hybrid]) / num_folds) ** 0.5
print(f"Mean Validation Accuracy: {mean_val_accuracy}, Std Validation Accuracy: {std_val_accuracy}")
print(f"Mean Validation Loss: {mean_val_loss}, Std Validation Loss: {std_val_loss}")
# Out:
# Mean Training Accuracy: 0.9993978500366211, Std Training Accuracy: 0.0003284766312051488
# Mean Training Loss: 0.0015891366871073841, Std Training Loss: 0.0007831921805197348
# Mean Validation Accuracy: 0.9993628025054931, Std Validation Accuracy: 0.0010564840526283562
# Mean Validation Loss: 0.002106306387577206, Std Validation Loss: 0.0026020671482271675

# %%
avg_report_hybrid = {
    'Class 0': {
        'precision': np.mean([r['0']['precision'] for r in classification_reports_hybrid]),
        'recall': np.mean([r['0']['recall'] for r in classification_reports_hybrid]),
        'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports_hybrid]),
        'support': np.sum([r['0']['support'] for r in classification_reports_hybrid])
    },
    'Class 1': {
        'precision': np.mean([r['1']['precision'] for r in classification_reports_hybrid]),
        'recall': np.mean([r['1']['recall'] for r in classification_reports_hybrid]),
        'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports_hybrid]),
        'support': np.sum([r['1']['support'] for r in classification_reports_hybrid])
    }
}

# Print the aggregated classification report
print("Average Classification Report across all folds:")
print(avg_report_hybrid)
# Out:
# Average Classification Report across all folds:
# {'Class 0': {'precision': np.float64(1.0), 'recall': np.float64(0.998691289520837), 'f1-score': np.float64(0.9993440681877385), 'support': np.float64(3137.0)}, 'Class 1': {'precision': np.float64(0.9987614869094404), 'recall': np.float64(1.0), 'f1-score': np.float64(0.9993792728840143), 'support': np.float64(3137.0)}}

# %%
import csv

# Define the file name for saving the metrics
csv_file = 'metrics_hybrid_borderline.csv'

headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']

# Combine training and validation metrics into a single list
all_metrics = []


# Collect the metrics and populate the data
for epoch in range(epochs_hybrid):
    # Training metrics for the current epoch
    train_loss = history_hybrid_borderline.history['loss'][epoch]
    train_accuracy = history_hybrid_borderline.history['accuracy'][epoch]

    # Validation metrics for the current epoch
    val_loss = history_hybrid_borderline.history['val_loss'][epoch]
    val_accuracy = history_hybrid_borderline.history['val_accuracy'][epoch]

    # Append the metrics for the current epoch
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

# Write the metrics to a CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the headers
    writer.writerow(headers)

    # Write the data
    writer.writerows(all_metrics)

# %% [markdown]
# ####Testing

# %%
hybrid_evaluation1 = hybrid_model.evaluate(x_test_padded1, y_test1, batch_size=4)
hybrid_accuracy1 = hybrid_evaluation1[1]

print("Hybrid Model Evaluation Results:")
print("Accuracy:", hybrid_accuracy1)
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9110 - loss: 0.7315
# Hybrid Model Evaluation Results:
# Accuracy: 0.9270833134651184

# %%
y_test_pred1 = (hybrid_model.predict(x_test_padded1) > 0.5).astype("int32").flatten()

test_report1 = classification_report(y_test1, y_test_pred1)

print("Classification Report on Test Dataset 1 :")
print(test_report1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Classification Report on Test Dataset 1 :
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       349
#            1       0.68      0.37      0.48        35
#
#     accuracy                           0.93       384
#    macro avg       0.81      0.68      0.72       384
# weighted avg       0.92      0.93      0.92       384

# %% [markdown]
# ###CNN + LSTM KMeansSMOTE Train and Test

# %%
hybrid_model = Model(inputs=static_input, outputs=output)
hybrid_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the CNN + LSTM model
epochs_hybrid = 10
history_hybrid_kmeans = hybrid_model.fit(
    x_train_resampled_kmeans,
    y_train_resampled_kmeans,
    batch_size=32,
    epochs=epochs_hybrid,
    validation_split=0.1,
)
# Out:
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9900 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 7.8846e-05
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9943 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 1.9948e-05
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9922 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 5.0045e-05
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9875 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 5.9602e-05
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9896 - loss: 0.0285 - val_accuracy: 1.0000 - val_loss: 2.3268e-04
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9939 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 1.3855e-04
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9931 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 2.5560e-05
# Epoch 8/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9919 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 7.9355e-05
# Epoch 9/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9953 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 1.9912e-05
# Epoch 10/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9937 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 1.3043e-05

# %%
# Convert the data to numpy arrays
x_train_np = np.array(x_train_resampled_kmeans)
y_train_np = np.array(y_train_resampled_kmeans)

# %%
from sklearn.model_selection import KFold
# Define the number of folds
num_folds = 10

# Initialize K-Fold cross-validator
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)  # You can set a random seed for reproducibility

# Initialize lists to store cross-validation results
accuracies = []
losses = []

# %%
# Initialize lists to store training and validation accuracies and losses
train_accuracies_hybrid = []
val_accuracies_hybrid = []
train_losses_hybrid = []
val_losses_hybrid = []
classification_reports_hybrid = []
# Iterate over the folds
fold = 0
for train_indices, val_indices in kf.split(x_train_np):
    fold += 1
    print(f"Training fold {fold}/{num_folds}")

    hybrid_model = Model(inputs=static_input, outputs=output)

    hybrid_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # Get the training and validation data for this fold
    x_train_fold = x_train_np[train_indices]
    y_train_fold = y_train_np[train_indices]
    x_val_fold = x_train_np[val_indices]
    y_val_fold = y_train_np[val_indices]

    # Early stopping callback
    early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

    # Train the model for this fold
    history = hybrid_model.fit(
        x_train_fold,
        y_train_fold,
        batch_size=32,
        epochs=epochs_hybrid,  # Make sure you define epochs_hybrid
        validation_data=(x_val_fold, y_val_fold),
        callbacks=[early_stopping],
    )

    # Evaluate the model on this fold for training and validation
    train_loss_hybrid, train_accuracy_hybrid = hybrid_model.evaluate(x_train_fold, y_train_fold)
    val_loss_hybrid, val_accuracy_hybrid = hybrid_model.evaluate(x_val_fold, y_val_fold)

    print(f"Fold {fold} - Training Loss: {train_loss_hybrid}, Training Accuracy: {train_accuracy_hybrid}")
    print(f"Fold {fold} - Validation Loss: {val_loss_hybrid}, Validation Accuracy: {val_accuracy_hybrid}")

    # Store the results for this fold
    train_accuracies_hybrid.append(train_accuracy_hybrid)
    val_accuracies_hybrid.append(val_accuracy_hybrid)
    train_losses_hybrid.append(train_loss_hybrid)
    val_losses_hybrid.append(val_loss_hybrid)

    # Evaluate the model
    y_pred = (hybrid_model.predict(x_val_fold) > 0.5).astype("int32").flatten()

    # Generate and store the classification report
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports_hybrid.append(report)

    # Print the classification report for this fold
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)
# Out:
# Training fold 1/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9947 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 1.2307e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9926 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 7.2148e-05
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9931 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 1.2088e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9899 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 9.5178e-05
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9955 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 2.3058e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.9634e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.6869e-05
# Fold 1 - Training Loss: 0.0002909849863499403, Training Accuracy: 1.0
# Fold 1 - Validation Loss: 7.2147959144786e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       327
#            1       1.00      1.00      1.00       301
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 2/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9935 - loss: 0.0213 - val_accuracy: 1.0000 - val_loss: 3.6043e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9928 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9946 - loss: 0.0171 - val_accuracy: 1.0000 - val_loss: 5.2344e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9947 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 1.8982e-04
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9913 - loss: 0.0266 - val_accuracy: 1.0000 - val_loss: 6.2318e-04
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9931 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 4.1399e-04
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9938 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 2.8643e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.7054e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.3435e-04
# Fold 2 - Training Loss: 0.00031807555933482945, Training Accuracy: 1.0
# Fold 2 - Validation Loss: 0.0001898158952826634, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       300
#            1       1.00      1.00      1.00       328
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 3/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9942 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 4.5177e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9953 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 3.9187e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9938 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 2.8534e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9927 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 6.9705e-04
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9961 - loss: 0.0126 - val_accuracy: 1.0000 - val_loss: 3.8677e-04
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9963 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 2.8675e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 3.0415e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.4625e-04
# Fold 3 - Training Loss: 0.0002581898297648877, Training Accuracy: 0.9998228549957275
# Fold 3 - Validation Loss: 0.00028534498414956033, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       316
#            1       1.00      1.00      1.00       312
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 4/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9938 - loss: 0.0173 - val_accuracy: 1.0000 - val_loss: 5.5059e-05
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9905 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 3.9873e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9946 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 3.0865e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9954 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 1.8138e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 2.5630e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.6544e-05
# Fold 4 - Training Loss: 0.00025584615650586784, Training Accuracy: 0.9998228549957275
# Fold 4 - Validation Loss: 5.505941589944996e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       323
#            1       1.00      1.00      1.00       305
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 5/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9960 - loss: 0.0158 - val_accuracy: 0.9984 - val_loss: 0.0036
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9941 - loss: 0.0156 - val_accuracy: 0.9984 - val_loss: 0.0044
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9938 - loss: 0.0157 - val_accuracy: 0.9984 - val_loss: 0.0045
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9965 - loss: 0.0179 - val_accuracy: 0.9984 - val_loss: 0.0037
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.9222e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0036
# Fold 5 - Training Loss: 0.00029319917666725814, Training Accuracy: 1.0
# Fold 5 - Validation Loss: 0.003621425712481141, Validation Accuracy: 0.9984050989151001
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       292
#            1       1.00      1.00      1.00       335
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 6/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9915 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 5.5564e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9941 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9953 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 9.0377e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9943 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 0.0011
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6094e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.0629e-04
# Fold 6 - Training Loss: 9.552340634400025e-05, Training Accuracy: 1.0
# Fold 6 - Validation Loss: 0.0005556383403018117, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       311
#            1       1.00      1.00      1.00       316
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 7/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9935 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 8.8251e-05
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9925 - loss: 0.0279 - val_accuracy: 1.0000 - val_loss: 1.1501e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9937 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 2.9107e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9937 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 3.3840e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9996 - loss: 0.0014
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.1444e-04
# Fold 7 - Training Loss: 0.0006014379323460162, Training Accuracy: 0.9998229146003723
# Fold 7 - Validation Loss: 8.825107215670869e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       308
#            1       1.00      1.00      1.00       319
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 8/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9936 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 1.4717e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9931 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 1.1892e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9920 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 4.5142e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9909 - loss: 0.0234 - val_accuracy: 1.0000 - val_loss: 5.8225e-04
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9971 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 3.6855e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.7226e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.9226e-04
# Fold 8 - Training Loss: 0.0001549290755065158, Training Accuracy: 1.0
# Fold 8 - Validation Loss: 0.00011891875328728929, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       327
#            1       1.00      1.00      1.00       300
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 9/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9940 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 5.9092e-05
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9894 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 5.9898e-05
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9933 - loss: 0.0181 - val_accuracy: 1.0000 - val_loss: 1.6429e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9928 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 1.4079e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.0223e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.9056e-05
# Fold 9 - Training Loss: 0.00019755303219426423, Training Accuracy: 1.0
# Fold 9 - Validation Loss: 5.90918971283827e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       322
#            1       1.00      1.00      1.00       305
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 10/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9951 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 2.4841e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9926 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 5.0853e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9937 - loss: 0.0244 - val_accuracy: 1.0000 - val_loss: 6.8847e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9918 - loss: 0.0249 - val_accuracy: 0.9984 - val_loss: 0.0033
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0840e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.6243e-04
# Fold 10 - Training Loss: 8.845132106216624e-05, Training Accuracy: 1.0
# Fold 10 - Validation Loss: 0.00024841472622938454, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       311
#            1       1.00      1.00      1.00       316
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------

# %%
# Calculate and print the mean and standard deviation of training accuracy and loss across folds
mean_train_accuracy = sum(train_accuracies_hybrid) / num_folds
std_train_accuracy = (sum([(acc - mean_train_accuracy) ** 2 for acc in train_accuracies_hybrid]) / num_folds) ** 0.5
mean_train_loss = sum(train_losses_hybrid) / num_folds
std_train_loss = (sum([(loss - mean_train_loss) ** 2 for loss in train_losses_hybrid]) / num_folds) ** 0.5
print(f"Mean Training Accuracy: {mean_train_accuracy}, Std Training Accuracy: {std_train_accuracy}")
print(f"Mean Training Loss: {mean_train_loss}, Std Training Loss: {std_train_loss}")

# Calculate and print the mean and standard deviation of validation accuracy and loss across folds
mean_val_accuracy = sum(val_accuracies_hybrid) / num_folds
std_val_accuracy = (sum([(acc - mean_val_accuracy) ** 2 for acc in val_accuracies_hybrid]) / num_folds) ** 0.5
mean_val_loss = sum(val_losses_hybrid) / num_folds
std_val_loss = (sum([(loss - mean_val_loss) ** 2 for loss in val_losses_hybrid]) / num_folds) ** 0.5
print(f"Mean Validation Accuracy: {mean_val_accuracy}, Std Validation Accuracy: {std_val_accuracy}")
print(f"Mean Validation Loss: {mean_val_loss}, Std Validation Loss: {std_val_loss}")
# Out:
# Mean Training Accuracy: 0.9999468624591827, Std Training Accuracy: 8.11689358052802e-05
# Mean Training Loss: 0.0002554190476075746, Std Training Loss: 0.0001390131608514625
# Mean Validation Accuracy: 0.99984050989151, Std Validation Accuracy: 0.00047847032546997074
# Mean Validation Loss: 0.0005294108756061178, Std Validation Loss: 0.0010408419551322771

# %%
avg_report_hybrid = {
    'Class 0': {
        'precision': np.mean([r['0']['precision'] for r in classification_reports_hybrid]),
        'recall': np.mean([r['0']['recall'] for r in classification_reports_hybrid]),
        'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports_hybrid]),
        'support': np.sum([r['0']['support'] for r in classification_reports_hybrid])
    },
    'Class 1': {
        'precision': np.mean([r['1']['precision'] for r in classification_reports_hybrid]),
        'recall': np.mean([r['1']['recall'] for r in classification_reports_hybrid]),
        'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports_hybrid]),
        'support': np.sum([r['1']['support'] for r in classification_reports_hybrid])
    }
}

# Print the aggregated classification report
print("Average Classification Report across all folds:")
print(avg_report_hybrid)
# Out:
# Average Classification Report across all folds:
# {'Class 0': {'precision': np.float64(1.0), 'recall': np.float64(0.9996575342465753), 'f1-score': np.float64(0.999828473413379), 'support': np.float64(3137.0)}, 'Class 1': {'precision': np.float64(0.9997023809523811), 'recall': np.float64(1.0), 'f1-score': np.float64(0.9998509687034277), 'support': np.float64(3137.0)}}

# %%
import csv

# Define the file name for saving the metrics
csv_file = 'metrics_hybrid_kmeans.csv'

headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']

# Combine training and validation metrics into a single list
all_metrics = []


# Collect the metrics and populate the data
for epoch in range(epochs_hybrid):
    # Training metrics for the current epoch
    train_loss = history_hybrid_kmeans.history['loss'][epoch]
    train_accuracy = history_hybrid_kmeans.history['accuracy'][epoch]

    # Validation metrics for the current epoch
    val_loss = history_hybrid_kmeans.history['val_loss'][epoch]
    val_accuracy = history_hybrid_kmeans.history['val_accuracy'][epoch]

    # Append the metrics for the current epoch
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

# Write the metrics to a CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the headers
    writer.writerow(headers)

    # Write the data
    writer.writerows(all_metrics)

# %% [markdown]
# ####Testing

# %%
hybrid_evaluation1 = hybrid_model.evaluate(x_test_padded1, y_test1, batch_size=4)
hybrid_accuracy1 = hybrid_evaluation1[1]

print("Hybrid Model Evaluation Results:")
print("Accuracy:", hybrid_accuracy1)
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9075 - loss: 0.7191
# Hybrid Model Evaluation Results:
# Accuracy: 0.921875

# %%
y_test_pred1 = (hybrid_model.predict(x_test_padded1) > 0.5).astype("int32").flatten()

test_report1 = classification_report(y_test1, y_test_pred1)

print("Classification Report on Test Dataset 1 :")
print(test_report1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Classification Report on Test Dataset 1 :
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       349
#            1       0.65      0.31      0.42        35
#
#     accuracy                           0.92       384
#    macro avg       0.79      0.65      0.69       384
# weighted avg       0.91      0.92      0.91       384

# %% [markdown]
# ###CNN + LSTM SVMSMOTE Train and Test

# %%
hybrid_model = Model(inputs=static_input, outputs=output)
hybrid_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the CNN + LSTM model
epochs_hybrid = 10
history_hybrid_svm = hybrid_model.fit(
    x_train_resampled_svm,
    y_train_resampled_svm,
    batch_size=32,
    epochs=epochs_hybrid,
    validation_split=0.1,
)
# Out:
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9915 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 1.2390e-06
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9953 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 2.9417e-06
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9955 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 4.9089e-07
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9940 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 1.3449e-05
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9953 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 3.0250e-06
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9936 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 3.6787e-07
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9945 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 2.2309e-06
# Epoch 8/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9968 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 1.3907e-06
# Epoch 9/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9945 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 4.0676e-07
# Epoch 10/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9941 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 1.4421e-06

# %%
# Convert the data to numpy arrays
x_train_np = np.array(x_train_resampled_svm)
y_train_np = np.array(y_train_resampled_svm)

# %%
from sklearn.model_selection import KFold
# Define the number of folds
num_folds = 10

# Initialize K-Fold cross-validator
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)  # You can set a random seed for reproducibility

# Initialize lists to store cross-validation results
accuracies = []
losses = []

# %%
# Initialize lists to store training and validation accuracies and losses
train_accuracies_hybrid = []
val_accuracies_hybrid = []
train_losses_hybrid = []
val_losses_hybrid = []
classification_reports_hybrid = []
# Iterate over the folds
fold = 0
for train_indices, val_indices in kf.split(x_train_np):
    fold += 1
    print(f"Training fold {fold}/{num_folds}")

    hybrid_model = Model(inputs=static_input, outputs=output)

    hybrid_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # Get the training and validation data for this fold
    x_train_fold = x_train_np[train_indices]
    y_train_fold = y_train_np[train_indices]
    x_val_fold = x_train_np[val_indices]
    y_val_fold = y_train_np[val_indices]

    # Early stopping callback
    early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

    # Train the model for this fold
    history = hybrid_model.fit(
        x_train_fold,
        y_train_fold,
        batch_size=32,
        epochs=epochs_hybrid,  # Make sure you define epochs_hybrid
        validation_data=(x_val_fold, y_val_fold),
        callbacks=[early_stopping],
    )

    # Evaluate the model on this fold for training and validation
    train_loss_hybrid, train_accuracy_hybrid = hybrid_model.evaluate(x_train_fold, y_train_fold)
    val_loss_hybrid, val_accuracy_hybrid = hybrid_model.evaluate(x_val_fold, y_val_fold)

    print(f"Fold {fold} - Training Loss: {train_loss_hybrid}, Training Accuracy: {train_accuracy_hybrid}")
    print(f"Fold {fold} - Validation Loss: {val_loss_hybrid}, Validation Accuracy: {val_accuracy_hybrid}")

    # Store the results for this fold
    train_accuracies_hybrid.append(train_accuracy_hybrid)
    val_accuracies_hybrid.append(val_accuracy_hybrid)
    train_losses_hybrid.append(train_loss_hybrid)
    val_losses_hybrid.append(val_loss_hybrid)

    # Evaluate the model
    y_pred = (hybrid_model.predict(x_val_fold) > 0.5).astype("int32").flatten()

    # Generate and store the classification report
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports_hybrid.append(report)

    # Print the classification report for this fold
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)
# Out:
# Training fold 1/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9935 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 6.1740e-05
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9924 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 9.4067e-05
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9960 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 7.5060e-05
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9962 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 2.9951e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.1203e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.8966e-05
# Fold 1 - Training Loss: 0.00015717693895567209, Training Accuracy: 1.0
# Fold 1 - Validation Loss: 6.174026930239052e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       327
#            1       1.00      1.00      1.00       301
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 2/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9929 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 1.0811e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9954 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 8.1650e-05
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9941 - loss: 0.0256 - val_accuracy: 1.0000 - val_loss: 6.8832e-05
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9966 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 8.2162e-05
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9906 - loss: 0.0311 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9921 - loss: 0.0227 - val_accuracy: 1.0000 - val_loss: 0.0010
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 4.5427e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.8912e-05
# Fold 2 - Training Loss: 0.00033733563032001257, Training Accuracy: 0.9998228549957275
# Fold 2 - Validation Loss: 6.883237801957875e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       300
#            1       1.00      1.00      1.00       328
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 3/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9941 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 3.0859e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9932 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 2.7349e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9944 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 3.6104e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9960 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 1.2949e-04
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9963 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 1.5661e-04
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9916 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 3.0001e-04
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9946 - loss: 0.0180 - val_accuracy: 1.0000 - val_loss: 2.2835e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 4.3310e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.4889e-04
# Fold 3 - Training Loss: 0.0003542545309755951, Training Accuracy: 0.9998228549957275
# Fold 3 - Validation Loss: 0.0001294851244892925, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       316
#            1       1.00      1.00      1.00       312
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 4/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9946 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 1.9814e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9971 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 1.1976e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9929 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 1.7338e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9966 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 9.8347e-05
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9929 - loss: 0.0186 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9931 - loss: 0.0279 - val_accuracy: 1.0000 - val_loss: 3.3481e-04
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9931 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 3.0944e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.1363e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.9506e-04
# Fold 4 - Training Loss: 0.00010958404891425744, Training Accuracy: 1.0
# Fold 4 - Validation Loss: 9.834673983277753e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       323
#            1       1.00      1.00      1.00       305
#
#     accuracy                           1.00       628
#    macro avg       1.00      1.00      1.00       628
# weighted avg       1.00      1.00      1.00       628
#
# ------------------------------------------------------------
# Training fold 5/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9960 - loss: 0.0144 - val_accuracy: 0.9984 - val_loss: 0.0040
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9945 - loss: 0.0163 - val_accuracy: 0.9984 - val_loss: 0.0031
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9949 - loss: 0.0170 - val_accuracy: 0.9984 - val_loss: 0.0022
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9959 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 2.9173e-04
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9937 - loss: 0.0190 - val_accuracy: 0.9984 - val_loss: 0.0085
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9973 - loss: 0.0114 - val_accuracy: 0.9984 - val_loss: 0.0081
# Epoch 7/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9967 - loss: 0.0089 - val_accuracy: 0.9984 - val_loss: 0.0075
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.1657e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.1097e-04
# Fold 5 - Training Loss: 0.00022508790425490588, Training Accuracy: 1.0
# Fold 5 - Validation Loss: 0.0002917280653491616, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       292
#            1       1.00      1.00      1.00       335
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 6/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9935 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 1.2046e-04
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9960 - loss: 0.0155 - val_accuracy: 1.0000 - val_loss: 8.1848e-05
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9965 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 3.4854e-05
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9944 - loss: 0.0126 - val_accuracy: 1.0000 - val_loss: 8.5179e-05
# Epoch 5/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9949 - loss: 0.0197 - val_accuracy: 1.0000 - val_loss: 1.7369e-04
# Epoch 6/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9950 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 4.5964e-05
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.3651e-05
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.8675e-05
# Fold 6 - Training Loss: 5.704129216610454e-05, Training Accuracy: 1.0
# Fold 6 - Validation Loss: 3.4853757824748755e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       311
#            1       1.00      1.00      1.00       316
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 7/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9941 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 5.7310e-05
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9964 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 8.9854e-05
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9954 - loss: 0.0119 - val_accuracy: 1.0000 - val_loss: 7.5027e-05
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9970 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 8.5869e-05
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.1589e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.6612e-05
# Fold 7 - Training Loss: 7.94876177678816e-05, Training Accuracy: 1.0
# Fold 7 - Validation Loss: 5.730976045015268e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       308
#            1       1.00      1.00      1.00       319
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 8/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9969 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 5.6828e-05
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9938 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 9.3965e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9942 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 1.1276e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9943 - loss: 0.0180 - val_accuracy: 1.0000 - val_loss: 1.7857e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0116e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.9334e-05
# Fold 8 - Training Loss: 6.889041105750948e-05, Training Accuracy: 1.0
# Fold 8 - Validation Loss: 5.6828121159924194e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       327
#            1       1.00      1.00      1.00       300
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 9/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9937 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 7.5539e-06
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9943 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 1.1441e-04
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9945 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 2.0812e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9959 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 1.3329e-04
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.8776e-05
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.6363e-06
# Fold 9 - Training Loss: 1.1591686416068114e-05, Training Accuracy: 1.0
# Fold 9 - Validation Loss: 7.5539364843280055e-06, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       322
#            1       1.00      1.00      1.00       305
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------
# Training fold 10/10
# Epoch 1/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9932 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 5.9738e-05
# Epoch 2/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9953 - loss: 0.0117 - val_accuracy: 0.9984 - val_loss: 0.0023
# Epoch 3/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9979 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 8.8337e-04
# Epoch 4/10
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9952 - loss: 0.0149 - val_accuracy: 0.9984 - val_loss: 0.0038
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.1216e-05
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.1587e-04
# Fold 10 - Training Loss: 3.130628101644106e-05, Training Accuracy: 1.0
# Fold 10 - Validation Loss: 5.973794759484008e-05, Validation Accuracy: 1.0
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       311
#            1       1.00      1.00      1.00       316
#
#     accuracy                           1.00       627
#    macro avg       1.00      1.00      1.00       627
# weighted avg       1.00      1.00      1.00       627
#
# ------------------------------------------------------------

# %%
# Calculate and print the mean and standard deviation of training accuracy and loss across folds
mean_train_accuracy = sum(train_accuracies_hybrid) / num_folds
std_train_accuracy = (sum([(acc - mean_train_accuracy) ** 2 for acc in train_accuracies_hybrid]) / num_folds) ** 0.5
mean_train_loss = sum(train_losses_hybrid) / num_folds
std_train_loss = (sum([(loss - mean_train_loss) ** 2 for loss in train_losses_hybrid]) / num_folds) ** 0.5
print(f"Mean Training Accuracy: {mean_train_accuracy}, Std Training Accuracy: {std_train_accuracy}")
print(f"Mean Training Loss: {mean_train_loss}, Std Training Loss: {std_train_loss}")

# Calculate and print the mean and standard deviation of validation accuracy and loss across folds
mean_val_accuracy = sum(val_accuracies_hybrid) / num_folds
std_val_accuracy = (sum([(acc - mean_val_accuracy) ** 2 for acc in val_accuracies_hybrid]) / num_folds) ** 0.5
mean_val_loss = sum(val_losses_hybrid) / num_folds
std_val_loss = (sum([(loss - mean_val_loss) ** 2 for loss in val_losses_hybrid]) / num_folds) ** 0.5
print(f"Mean Validation Accuracy: {mean_val_accuracy}, Std Validation Accuracy: {std_val_accuracy}")
print(f"Mean Validation Loss: {mean_val_loss}, Std Validation Loss: {std_val_loss}")
# Out:
# Mean Training Accuracy: 0.9999645709991455, Std Training Accuracy: 7.085800170898437e-05
# Mean Training Loss: 0.00014317563418444478, Std Training Loss: 0.0001170936061738026
# Mean Validation Accuracy: 1.0, Std Validation Accuracy: 0.0
# Mean Validation Loss: 8.664161005071947e-05, Std Validation Loss: 7.508670107205481e-05

# %%
avg_report_hybrid = {
    'Class 0': {
        'precision': np.mean([r['0']['precision'] for r in classification_reports_hybrid]),
        'recall': np.mean([r['0']['recall'] for r in classification_reports_hybrid]),
        'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports_hybrid]),
        'support': np.sum([r['0']['support'] for r in classification_reports_hybrid])
    },
    'Class 1': {
        'precision': np.mean([r['1']['precision'] for r in classification_reports_hybrid]),
        'recall': np.mean([r['1']['recall'] for r in classification_reports_hybrid]),
        'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports_hybrid]),
        'support': np.sum([r['1']['support'] for r in classification_reports_hybrid])
    }
}

# Print the aggregated classification report
print("Average Classification Report across all folds:")
print(avg_report_hybrid)
# Out:
# Average Classification Report across all folds:
# {'Class 0': {'precision': np.float64(1.0), 'recall': np.float64(1.0), 'f1-score': np.float64(1.0), 'support': np.float64(3137.0)}, 'Class 1': {'precision': np.float64(1.0), 'recall': np.float64(1.0), 'f1-score': np.float64(1.0), 'support': np.float64(3137.0)}}

# %%
import csv

# Define the file name for saving the metrics
csv_file = 'metrics_hybrid_svm.csv'

headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']

# Combine training and validation metrics into a single list
all_metrics = []


# Collect the metrics and populate the data
for epoch in range(epochs_hybrid):
    # Training metrics for the current epoch
    train_loss = history_hybrid_svm.history['loss'][epoch]
    train_accuracy = history_hybrid_svm.history['accuracy'][epoch]

    # Validation metrics for the current epoch
    val_loss = history_hybrid_svm.history['val_loss'][epoch]
    val_accuracy = history_hybrid_svm.history['val_accuracy'][epoch]

    # Append the metrics for the current epoch
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

# Write the metrics to a CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the headers
    writer.writerow(headers)

    # Write the data
    writer.writerows(all_metrics)

# %% [markdown]
# ####Testing

# %%
hybrid_evaluation1 = hybrid_model.evaluate(x_test_padded1, y_test1, batch_size=4)
hybrid_accuracy1 = hybrid_evaluation1[1]

print("Hybrid Model Evaluation Results:")
print("Accuracy:", hybrid_accuracy1)
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9232 - loss: 0.7364
# Hybrid Model Evaluation Results:
# Accuracy: 0.9296875

# %%
y_test_pred1 = (hybrid_model.predict(x_test_padded1) > 0.5).astype("int32").flatten()

test_report1 = classification_report(y_test1, y_test_pred1)

print("Classification Report on Test Dataset 1 :")
print(test_report1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Classification Report on Test Dataset 1 :
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       349
#            1       0.79      0.31      0.45        35
#
#     accuracy                           0.93       384
#    macro avg       0.86      0.65      0.71       384
# weighted avg       0.92      0.93      0.92       384

# %% [markdown]
# ##Evaluation

# %%
torch.cuda.empty_cache()

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.model_selection import KFold
import seaborn as sns
import matplotlib.pyplot as plt

def show_confusion_matrix(confusion_matrix):
        hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
        hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
        hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')

        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')

# %% [markdown]
# ###Hybrid

# %% [markdown]
# ####BorderlineSMOTE

# %%
import matplotlib.pyplot as plt
train_loss_hybrid = history_hybrid_borderline.history['loss']
val_loss_hybrid = history_hybrid_borderline.history['val_loss']
# Plot the loss curves
plt.plot(range(1, len(train_loss_hybrid) + 1), train_loss_hybrid, label='Training Loss')
plt.plot(range(1, len(val_loss_hybrid) + 1), val_loss_hybrid, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Hybrid CNN+LSTM')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
accuracy_hybrid = history_hybrid_borderline.history['accuracy']
val_accuracy_hybrid = history_hybrid_borderline.history['val_accuracy']
# Plot the loss curves
plt.plot(range(1, len(accuracy_hybrid) + 1), accuracy_hybrid, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy_hybrid) + 1), val_accuracy_hybrid, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Hybrid CNN+LSTM')
plt.legend()
plt.show()

# %%
predictions_hybrid_1 = hybrid_model.predict(x_test_padded1)
predicted_labels_hybrid_1 = (predictions_hybrid_1 > 0.5).astype(int)
cm_hybrid_1 = confusion_matrix(y_test1,predicted_labels_hybrid_1)
show_confusion_matrix(cm_hybrid_1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ####KMeansSMOTE

# %%
import matplotlib.pyplot as plt
train_loss_hybrid = history_hybrid_kmeans.history['loss']
val_loss_hybrid = history_hybrid_kmeans.history['val_loss']
# Plot the loss curves
plt.plot(range(1, len(train_loss_hybrid) + 1), train_loss_hybrid, label='Training Loss')
plt.plot(range(1, len(val_loss_hybrid) + 1), val_loss_hybrid, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Hybrid CNN+LSTM')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
accuracy_hybrid = history_hybrid_kmeans.history['accuracy']
val_accuracy_hybrid = history_hybrid_kmeans.history['val_accuracy']
# Plot the loss curves
plt.plot(range(1, len(accuracy_hybrid) + 1), accuracy_hybrid, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy_hybrid) + 1), val_accuracy_hybrid, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Hybrid CNN+LSTM')
plt.legend()
plt.show()

# %%
predictions_hybrid_1 = hybrid_model.predict(x_test_padded1)
predicted_labels_hybrid_1 = (predictions_hybrid_1 > 0.5).astype(int)
cm_hybrid_1 = confusion_matrix(y_test1,predicted_labels_hybrid_1)
show_confusion_matrix(cm_hybrid_1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ####SVMSMOTE

# %%
import matplotlib.pyplot as plt
train_loss_hybrid = history_hybrid_svm.history['loss']
val_loss_hybrid = history_hybrid_svm.history['val_loss']
# Plot the loss curves
plt.plot(range(1, len(train_loss_hybrid) + 1), train_loss_hybrid, label='Training Loss')
plt.plot(range(1, len(val_loss_hybrid) + 1), val_loss_hybrid, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Hybrid CNN+LSTM')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
accuracy_hybrid = history_hybrid_svm.history['accuracy']
val_accuracy_hybrid = history_hybrid_svm.history['val_accuracy']
# Plot the loss curves
plt.plot(range(1, len(accuracy_hybrid) + 1), accuracy_hybrid, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy_hybrid) + 1), val_accuracy_hybrid, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Hybrid CNN+LSTM')
plt.legend()
plt.show()

# %%
predictions_hybrid_1 = hybrid_model.predict(x_test_padded1)
predicted_labels_hybrid_1 = (predictions_hybrid_1 > 0.5).astype(int)
cm_hybrid_1 = confusion_matrix(y_test1,predicted_labels_hybrid_1)
show_confusion_matrix(cm_hybrid_1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# !zip -r CNNLSTMMarginLoss.zip ./* -x "sample_data/*"
# Out:
#   adding: idwiki_word2vec_768_new_lower.model (deflated 72%)
#   adding: idwiki_word2vec_768_new_lower.model.syn1neg.npy (deflated 7%)
#   adding: idwiki_word2vec_768_new_lower.model.wv.vectors.npy (deflated 7%)
#   adding: metrics_hybrid_borderline.csv (deflated 49%)
#   adding: metrics_hybrid_kmeans.csv (deflated 51%)
#   adding: metrics_hybrid_svm.csv (deflated 51%)
#   adding: model_w2v.zip (stored 0%)
#   adding: pilpres_test_clean.csv (deflated 62%)
#   adding: pilpres_train_balanced_clean.csv (deflated 75%)
