# %% [markdown]
# ###Install Library and preparing

# %%
# !pip install -q torch
# !pip install -q tf
# !pip install -q gdown
# !pip install -q transformers[torch] accelerate -U
# !pip install -q accelerate -U
# !pip install -q datasets
# !pip install -q gensim
# !pip install -q evaluate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 91.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.5 MB/s eta 0:00:00

# %% [markdown]
# ###Import Library

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import re
import gc
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report
from collections import Counter
import tensorflow as tf
from gensim.models import Word2Vec
from transformers import AutoTokenizer, AutoModelForSequenceClassification,Trainer, AutoConfig, TrainingArguments, EarlyStoppingCallback
from tensorflow.keras.layers import Input, Embedding, Conv1D, GlobalMaxPooling1D, MaxPooling1D, Dense, Flatten, concatenate, BatchNormalization,LSTM, Dropout, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import backend as K
from datasets import load_dataset
import evaluate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import he_normal
from sklearn.model_selection import StratifiedKFold
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import BorderlineSMOTE, KMeansSMOTE, SVMSMOTE

import os
os.environ["WANDB_DISABLED"] = "true"

# %% [markdown]
# ###Read Dataset and load Word2Vec

# %%
df = pd.read_csv("/content/news_train_balanced_clean.csv")

# %%
df_test1 = pd.read_csv("/content/news_test_clean.csv")

# %%
df.head()
# Out:
#                                                 Text  Label
# 0  Politikus Gerindra Sentil Wagub Uu karena Sepe...      0
# 1  Sahroni: Buru Pembocor Data Lebih Penting dari...      0
# 2  Sekjen Golkar Ungkap Pertemuan Puan dan Airlan...      0
# 3  Partai Buruh Sebut Masa Kampanye 75 Hari Langg...      0
# 4  Mahfud Minta Publik Tak Terprovokasi Manuver P...      0

# %%
df.shape
# Out:
# (37750, 2)

# %%
print(df['Label'].value_counts())
# Out:
# Label
# 0    18875
# 1    18875
# Name: count, dtype: int64

# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
gc.collect()
print(gensim.__version__)
# Load Pretrained Word Embeddings (Word2Vec)
# !gdown --id 1QYj5FruufaPq2mZgC6lZlq2Uw2E004Og
# !gdown --id 1F9QsHO7FPIPq3nL_I0zCkZFvq3OVcJrB
# !gdown --id 1VUjxpH10baOw439V-YAAVVbtyI8iLgG5
# Out:
# 4.4.0

# %%
import os
import gdown
import zipfile

'''https://drive.google.com/file/d/1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3/view?usp=sharing'''

file_id = '1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3'

url = f'https://drive.google.com/uc?id={file_id}'
output_zip = 'model_w2v.zip'

if not os.path.exists('idwiki_word2vec_768_new_lower.model'):
    print("Downloading Model...")
    gdown.download(url, output_zip, quiet=False)

    print("Extracting File...")
    with zipfile.ZipFile(output_zip, 'r') as zip_ref:
        zip_ref.extractall('/content/')
    print("Done.")
else:
    print("Model Available")
# Out:
# Downloading Model...
# Downloading...
# From (original): https://drive.google.com/uc?id=1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3
# From (redirected): https://drive.google.com/uc?id=1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3&confirm=t&uuid=631c6699-d8c2-4561-bdbe-f081f153c4ab
# To: /content/model_w2v.zip
# 100%|██████████| 2.56G/2.56G [00:13<00:00, 188MB/s]
# Extracting File...
# Done.

# %%
word_embeddings = Word2Vec.load('/content/idwiki_word2vec_768_new_lower.model')
#word_embeddings = Word2Vec.load('/content/modelword2vec/idwiki_word2vec_768_new_lower.model')

# %% [markdown]
# ###Split Dataset

# %%
x_train = df['Text']
y_train = df['Label']

# %%
x_test1 = df_test1['Text']
y_test1 = np.array(df_test1['Label'])

# %% [markdown]
# ###Define Loss Function, Tokenization, Word Embeddings and Oversampling

# %%
# # Define the margin loss function
# def margin_loss(y_true, y_pred):
#     margin = K.constant(0.1)
#     y_true_float = K.cast(y_true, dtype='float32')  # Convert y_true to float32
#     squared_difference_pos = K.square(K.maximum(0.9 - y_pred, 0))
#     squared_difference_neg = K.square(K.maximum(y_pred - 0.1, 0))
#     loss_pos = K.mean(y_true_float * squared_difference_pos)
#     loss_neg = K.mean((1 - y_true_float) * squared_difference_neg)
#     total_loss = loss_pos + lambda_val * loss_neg
#     return total_loss

# %%
# # Define the model architectures
# #embedding_dim = 300
# #max_sequence_length = 100
# lambda_val = 0.7  # Lambda value for margin loss
# #num_words = 100000

# %%
# Create word index
word_index = {word: index + 1 for index, word in enumerate(word_embeddings.wv.index_to_key)}

# Create embedding matrix
embedding_dim = word_embeddings.vector_size
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    if word in word_embeddings.wv:
        embedding_vector = word_embeddings.wv[word]
        embedding_matrix[i] = embedding_vector

# %%
tokenizer = Tokenizer(num_words=len(word_index) + 1, oov_token='<OOV>')
tokenizer.fit_on_texts(x_train.astype(str).fillna(''))

# Convert text to sequences and pad
x_train_sequences = tokenizer.texts_to_sequences(x_train.astype(str).fillna(''))
x_test_sequences1 = tokenizer.texts_to_sequences(x_test1.astype(str).fillna(''))
# x_test_sequences2 = tokenizer.texts_to_sequences(x_test2)
# x_test_sequences3 = tokenizer.texts_to_sequences(x_test3)

# Determine max sequence length based on your data
max_sequence_length = max(max(len(seq) for seq in x_train_sequences), max(len(seq) for seq in x_test_sequences1))

x_train_padded = pad_sequences(x_train_sequences, maxlen=max_sequence_length, padding='post')
x_test_padded1 = pad_sequences(x_test_sequences1, maxlen=max_sequence_length, padding='post')
# x_test_padded2 = pad_sequences(x_test_sequences2, maxlen=max_sequence_length, padding='post')
# x_test_padded3 = pad_sequences(x_test_sequences3, maxlen=max_sequence_length, padding='post')

# %%
x_train_flat = x_train_padded.reshape(x_train_padded.shape[0], -1)

# %% [markdown]
# ####Oversampling with BorderlineSMOTE

# %%
borderline_smote = BorderlineSMOTE(random_state=42)
x_train_resampled_flat_borderline, y_train_resampled_borderline = borderline_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_borderline = x_train_resampled_flat_borderline.reshape(x_train_resampled_flat_borderline.shape[0], max_sequence_length)

# %% [markdown]
# ####Oversampling with KMeansSMOTE

# %%
kmeans_smote = KMeansSMOTE(random_state=42, cluster_balance_threshold=0.2)
x_train_resampled_flat_kmeans, y_train_resampled_kmeans = kmeans_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_kmeans = x_train_resampled_flat_kmeans.reshape(x_train_resampled_flat_kmeans.shape[0], max_sequence_length)

# %% [markdown]
# ####Oversampling with SVMSMOTE

# %%
svm_smote = SVMSMOTE(random_state=42)
x_train_resampled_flat_svm, y_train_resampled_svm = svm_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_svm = x_train_resampled_flat_svm.reshape(x_train_resampled_flat_svm.shape[0], max_sequence_length)

# %%
torch.cuda.empty_cache()
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
from google.colab import drive
drive.flush_and_unmount()
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %% [markdown]
# ##CNN Model

# %%
# Define the architecture of the static model with he_normal initialization
static_input = Input(shape=(max_sequence_length,))
static_embedding = Embedding(len(word_index) + 1, embedding_dim, input_length=max_sequence_length, trainable=False)(static_input)  # Removed weights parameter

#Convolutional Layers
static_cnn_output = Conv1D(128, 3, activation='relu', kernel_initializer=he_normal())(static_embedding)  # Use he_normal initialization
static_cnn_output = MaxPooling1D(2)(static_cnn_output)
static_cnn_output = GlobalMaxPooling1D()(static_cnn_output)
static_cnn_output = Dropout(0.5)(static_cnn_output)
batch_norm_layer = BatchNormalization()(static_cnn_output)

#Fully Connected Layers
static_dense_output = Dense(128, activation='relu', kernel_initializer=he_normal())(batch_norm_layer)  # Use he_normal initialization
static_dense_output = Dropout(0.5)(static_dense_output)
output = Dense(1, activation='sigmoid')(static_dense_output)

# Create the static model
static_model = Model(inputs=static_input, outputs=output)
static_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

# %% [markdown]
# ###CNN BorderlineSMOTE Train and Test

# %%
# Train the static model
epochs_static = 10
history_static = static_model.fit(
    x_train_resampled_borderline,
    y_train_resampled_borderline,
    batch_size=32,
    epochs=epochs_static,
    validation_split=0.1,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.8841 - loss: 0.2741 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 30s 28ms/step - accuracy: 0.9852 - loss: 0.0460 - val_accuracy: 1.0000 - val_loss: 8.3260e-04
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 30s 28ms/step - accuracy: 0.9917 - loss: 0.0280 - val_accuracy: 1.0000 - val_loss: 8.1949e-04
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 28ms/step - accuracy: 0.9935 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 5/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 30s 28ms/step - accuracy: 0.9940 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 2.5855e-04
# Epoch 6/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 28ms/step - accuracy: 0.9949 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 7.8720e-04
# Epoch 7/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 28ms/step - accuracy: 0.9944 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 8/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 28ms/step - accuracy: 0.9952 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 8.7562e-04

# %% [markdown]
# ####Cross-Validation Train

# %%
from sklearn.model_selection import KFold
# Define the number of folds
num_folds = 10

# Initialize K-Fold cross-validator
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)  # You can set a random seed for reproducibility

# Initialize lists to store cross-validation results
accuracies = []
losses = []

# %%
# Convert the data to numpy arrays
x_train_np = np.array(x_train_resampled_borderline)
y_train_np = np.array(y_train_resampled_borderline)

# %%
# Initialize lists to store training and validation accuracies and losses
train_accuracies_static = []
val_accuracies_static = []
train_losses_static = []
val_losses_static = []
classification_reports = []
# Iterate over the folds
fold = 0
for train_indices, val_indices in kf.split(x_train_np):
    fold += 1
    print(f"Training fold {fold}/{num_folds}")

    static_model = Model(inputs=static_input, outputs=output)

    static_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # Get the training and validation data for this fold
    x_train_fold = x_train_np[train_indices]
    y_train_fold = y_train_np[train_indices]
    x_val_fold = x_train_np[val_indices]
    y_val_fold = y_train_np[val_indices]

    # Early stopping callback
    early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

    # Train the model for this fold
    static = static_model.fit(
        x_train_fold,
        y_train_fold,
        batch_size=32,
        epochs=epochs_static,  # Make sure you define epochs_hybrid
        validation_data=(x_val_fold, y_val_fold),
        callbacks=[early_stopping],
    )

    # Evaluate the model on this fold for training and validation
    train_loss_static, train_accuracy_static = static_model.evaluate(x_train_fold, y_train_fold)
    val_loss_static, val_accuracy_static = static_model.evaluate(x_val_fold, y_val_fold)

    print(f"Fold {fold} - Training Loss: {train_loss_static}, Training Accuracy: {train_accuracy_static}")
    print(f"Fold {fold} - Validation Loss: {val_loss_static}, Validation Accuracy: {val_accuracy_static}")

    # Store the results for this fold
    train_accuracies_static.append(train_accuracy_static)
    val_accuracies_static.append(val_accuracy_static)
    train_losses_static.append(train_loss_static)
    val_losses_static.append(val_loss_static)

    # Evaluate the model
    y_pred = (static_model.predict(x_val_fold) > 0.5).astype("int32").flatten()

    # Generate and store the classification report
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports.append(report)

    # Print the classification report for this fold
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)
# Out:
# Training fold 1/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - accuracy: 0.9948 - loss: 0.0193 - val_accuracy: 0.9981 - val_loss: 0.0067
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 28ms/step - accuracy: 0.9946 - loss: 0.0202 - val_accuracy: 0.9987 - val_loss: 0.0081
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 28ms/step - accuracy: 0.9959 - loss: 0.0181 - val_accuracy: 0.9981 - val_loss: 0.0088
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 28ms/step - accuracy: 0.9953 - loss: 0.0169 - val_accuracy: 0.9968 - val_loss: 0.0111
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.9987 - loss: 0.0086
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9973 - loss: 0.0091
# Fold 1 - Training Loss: 0.005439274478703737, Training Accuracy: 0.9992052912712097
# Fold 1 - Validation Loss: 0.006713546812534332, Validation Accuracy: 0.9981456995010376
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1884
#            1       1.00      1.00      1.00      1891
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 2/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - accuracy: 0.9948 - loss: 0.0179 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 27ms/step - accuracy: 0.9955 - loss: 0.0166 - val_accuracy: 0.9987 - val_loss: 0.0061
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9957 - loss: 0.0167 - val_accuracy: 0.9987 - val_loss: 0.0061
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9975 - loss: 0.0115 - val_accuracy: 0.9987 - val_loss: 0.0060
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9990 - loss: 0.0071
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9983 - loss: 0.0122
# Fold 2 - Training Loss: 0.004986434243619442, Training Accuracy: 0.9993524551391602
# Fold 2 - Validation Loss: 0.004107877146452665, Validation Accuracy: 0.9994701743125916
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1895
#            1       1.00      1.00      1.00      1880
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 3/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9945 - loss: 0.0219 - val_accuracy: 0.9992 - val_loss: 0.0045
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 27ms/step - accuracy: 0.9971 - loss: 0.0126 - val_accuracy: 0.9989 - val_loss: 0.0052
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9962 - loss: 0.0143 - val_accuracy: 0.9992 - val_loss: 0.0047
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9962 - loss: 0.0150 - val_accuracy: 0.9992 - val_loss: 0.0049
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9988 - loss: 0.0069
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9984 - loss: 0.0069
# Fold 3 - Training Loss: 0.004852205980569124, Training Accuracy: 0.9992936253547668
# Fold 3 - Validation Loss: 0.004512948449701071, Validation Accuracy: 0.9992052912712097
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1862
#            1       1.00      1.00      1.00      1913
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 4/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9958 - loss: 0.0166 - val_accuracy: 0.9992 - val_loss: 0.0043
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.
- val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9983 - loss: 0.0090 - val_accuracy: 0.9997 - val_loss: 0.0027
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9978 - loss: 0.0109 - val_accuracy: 0.9995 - val_loss: 0.0024
# Epoch 5/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9983 - loss: 0.0086 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 6/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9978 - loss: 0.0107 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 7/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9980 - loss: 0.0092 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 8/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9983 - loss: 0.0087 - val_accuracy: 0.9992 - val_loss: 0.0029
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9989 - loss: 0.0079
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9998 - loss: 0.0016
# Fold 8 - Training Loss: 0.004972805734723806, Training Accuracy: 0.9993230104446411
# Fold 8 - Validation Loss: 0.002084009815007448, Validation Accuracy: 0.9997351169586182
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1907
#            1       1.00      1.00      1.00      1868
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 9/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9977 - loss: 0.0118 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9977 - loss: 0.0096 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9985 - loss: 0.0074 - val_accuracy: 0.9997 - val_loss: 0.0022
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9979 - loss: 0.0097 - val_accuracy: 0.9997 - val_loss: 0.0022
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9989 - loss: 0.0073
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9996 - loss: 0.0026
# Fold 9 - Training Loss: 0.004811321385204792, Training Accuracy: 0.9993230104446411
# Fold 9 - Validation Loss: 0.0021149360109120607, Validation Accuracy: 0.9997351169586182
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1930
#            1       1.00      1.00      1.00      1845
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 10/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 37s 31ms/step - accuracy: 0.9971 - loss: 0.0151 - val_accuracy: 0.9992 - val_loss: 0.0058
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9978 - loss: 0.0112 - val_accuracy: 0.9992 - val_loss: 0.0056
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9984 - loss: 0.0107 - val_accuracy: 0.9992 - val_loss: 0.0055
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 27ms/step - accuracy: 0.9977 - loss: 0.0114 - val_accuracy: 0.9992 - val_loss: 0.0061
# Epoch 5/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9979 - loss: 0.0102 - val_accuracy: 0.9992 - val_loss: 0.0054
# Epoch 6/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9978 - loss: 0.0088 - val_accuracy: 0.9992 - val_loss: 0.0059
# Epoch 7/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9974 - loss: 0.0106 - val_accuracy: 0.9992 - val_loss: 0.0061
# Epoch 8/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9989 - loss: 0.0072 - val_accuracy: 0.9992 - val_loss: 0.0062
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9989 - loss: 0.0059
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9987 - loss: 0.0079
# Fold 10 - Training Loss: 0.004372947383671999, Training Accuracy: 0.9993524551391602
# Fold 10 - Validation Loss: 0.005372324958443642, Validation Accuracy: 0.9992052912712097
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1873
#            1       1.00      1.00      1.00      1902
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------

# %%
# Calculate and print the mean and standard deviation of training accuracy and loss across folds
mean_train_accuracy = sum(train_accuracies_static) / num_folds
std_train_accuracy = (sum([(acc - mean_train_accuracy) ** 2 for acc in train_accuracies_static]) / num_folds) ** 0.5
mean_train_loss = sum(train_losses_static) / num_folds
std_train_loss = (sum([(loss - mean_train_loss) ** 2 for loss in train_losses_static]) / num_folds) ** 0.5
print(f"Mean Training Accuracy: {mean_train_accuracy}, Std Training Accuracy: {std_train_accuracy}")
print(f"Mean Training Loss: {mean_train_loss}, Std Training Loss: {std_train_loss}")

# Calculate and print the mean and standard deviation of validation accuracy and loss across folds
mean_val_accuracy = sum(val_accuracies_static) / num_folds
std_val_accuracy = (sum([(acc - mean_val_accuracy) ** 2 for acc in val_accuracies_static]) / num_folds) ** 0.5
mean_val_loss = sum(val_losses_static) / num_folds
std_val_loss = (sum([(loss - mean_val_loss) ** 2 for loss in val_losses_static]) / num_folds) ** 0.5
print(f"Mean Validation Accuracy: {mean_val_accuracy}, Std Validation Accuracy: {std_val_accuracy}")
print(f"Mean Validation Loss: {mean_val_loss}, Std Validation Loss: {std_val_loss}")
# Out:
# Mean Training Accuracy: 0.9993289232254028, Std Training Accuracy: 6.28548928122541e-05
# Mean Training Loss: 0.0047917908523231745, Std Training Loss: 0.00041706400481378037
# Mean Validation Accuracy: 0.9991258263587952, Std Validation Accuracy: 0.0005170646605335977
# Mean Validation Loss: 0.004953793692402541, Std Validation Loss: 0.00245181208865472

# %%
avg_report = {
    'Class 0': {
        'precision': np.mean([r['0']['precision'] for r in classification_reports]),
        'recall': np.mean([r['0']['recall'] for r in classification_reports]),
        'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports]),
        'support': np.sum([r['0']['support'] for r in classification_reports])
    },
    'Class 1': {
        'precision': np.mean([r['1']['precision'] for r in classification_reports]),
        'recall': np.mean([r['1']['recall'] for r in classification_reports]),
        'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports]),
        'support': np.sum([r['1']['support'] for r in classification_reports])
    }
}

# Print the aggregated classification report
print("Average Classification Report across all folds:")
print(avg_report)
# Out:
# Average Classification Report across all folds:
# {'Class 0': {'precision': np.float64(1.0), 'recall': np.float64(0.9982449204342678), 'f1-score': np.float64(0.9991214160011477), 'support': np.float64(18875.0)}, 'Class 1': {'precision': np.float64(0.9982618768118128), 'recall': np.float64(1.0), 'f1-score': np.float64(0.9991299215291252), 'support': np.float64(18875.0)}}

# %%
print(history_static.history.keys())
num_epochs = len(history_static.history['loss'])
print(f"Number of epochs: {num_epochs}")
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Number of epochs: 8

# %%
import csv

# Define the file name for saving the metrics
csv_file = 'metrics_CNN_BorderlineSMOTE.csv'

# Define headers for training and validation metrics

headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']

# Combine training and validation metrics into a single list
all_metrics = []

num_epochs = len(history_static.history['loss'])
print(f"Number of epochs: {num_epochs}")

# Collect the metrics and populate the data
for epoch in range(num_epochs):
    # Training metrics for the current epoch
    train_loss = history_static.history['loss'][epoch]
    train_accuracy = history_static.history['accuracy'][epoch]

    # Validation metrics for the current epoch
    val_loss = history_static.history['val_loss'][epoch]
    val_accuracy = history_static.history['val_accuracy'][epoch]

    # Append the metrics for the current epoch
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

# Write the metrics to a CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the headers
    writer.writerow(headers)

    # Write the data
    writer.writerows(all_metrics)
# Out:
# Number of epochs: 8

# %% [markdown]
# ####Testing

# %%
# Evaluate the static model
static_evaluation1 = static_model.evaluate(x_test_padded1, y_test1, batch_size=32)
static_accuracy1 = static_evaluation1[1]

print("Static Model Evaluation Results:")
print("Accuracy:", static_accuracy1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9776 - loss: 0.0646
# Static Model Evaluation Results:
# Accuracy: 0.9795547723770142

# %%
y_test_pred1 = (static_model.predict(x_test_padded1) > 0.5).astype("int32").flatten()

test_report1 = classification_report(y_test1, y_test_pred1)

print("Classification Report on Test Dataset 1 :")
print(test_report1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Classification Report on Test Dataset 1 :
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2097
#            1       0.72      0.93      0.81       104
#
#     accuracy                           0.98      2201
#    macro avg       0.86      0.96      0.90      2201
# weighted avg       0.98      0.98      0.98      2201

# %% [markdown]
# ###CNN KmeansSMOTE Train and Test

# %%
# Create the static model
static_model = Model(inputs=static_input, outputs=output)
static_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the static model
epochs_static = 10
history_static_kmeans = static_model.fit(
    x_train_resampled_kmeans,
    y_train_resampled_kmeans,
    batch_size=32,
    epochs=epochs_static,
    validation_split=0.1,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9984 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9982 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 9.2111e-04
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9980 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9979 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 4.8627e-04
# Epoch 5/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9981 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 2.2763e-04
# Epoch 6/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9980 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 7/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9982 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 3.8430e-04
# Epoch 8/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 27ms/step - accuracy: 0.9984 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 4.2558e-04

# %% [markdown]
# ####Cross-Validation Train

# %%
from sklearn.model_selection import KFold
# Define the number of folds
num_folds = 10

# Initialize K-Fold cross-validator
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)  # You can set a random seed for reproducibility

# Initialize lists to store cross-validation results
accuracies = []
losses = []

# %%
# Convert the data to numpy arrays
x_train_np = np.array(x_train_resampled_kmeans)
y_train_np = np.array(y_train_resampled_kmeans)

# %%
# Initialize lists to store training and validation accuracies and losses
train_accuracies_static = []
val_accuracies_static = []
train_losses_static = []
val_losses_static = []
classification_reports = []
# Iterate over the folds
fold = 0
for train_indices, val_indices in kf.split(x_train_np):
    fold += 1
    print(f"Training fold {fold}/{num_folds}")

    static_model = Model(inputs=static_input, outputs=output)

    static_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # Get the training and validation data for this fold
    x_train_fold = x_train_np[train_indices]
    y_train_fold = y_train_np[train_indices]
    x_val_fold = x_train_np[val_indices]
    y_val_fold = y_train_np[val_indices]

    # Early stopping callback
    early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

    # Train the model for this fold
    static = static_model.fit(
        x_train_fold,
        y_train_fold,
        batch_size=32,
        epochs=epochs_static,  # Make sure you define epochs_hybrid
        validation_data=(x_val_fold, y_val_fold),
        callbacks=[early_stopping],
    )

    # Evaluate the model on this fold for training and validation
    train_loss_static, train_accuracy_static = static_model.evaluate(x_train_fold, y_train_fold)
    val_loss_static, val_accuracy_static = static_model.evaluate(x_val_fold, y_val_fold)

    print(f"Fold {fold} - Training Loss: {train_loss_static}, Training Accuracy: {train_accuracy_static}")
    print(f"Fold {fold} - Validation Loss: {val_loss_static}, Validation Accuracy: {val_accuracy_static}")

    # Store the results for this fold
    train_accuracies_static.append(train_accuracy_static)
    val_accuracies_static.append(val_accuracy_static)
    train_losses_static.append(train_loss_static)
    val_losses_static.append(val_loss_static)

    # Evaluate the model
    y_pred = (static_model.predict(x_val_fold) > 0.5).astype("int32").flatten()

    # Generate and store the classification report
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports.append(report)

    # Print the classification report for this fold
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)
# Out:
# Training fold 1/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9978 - loss: 0.0113 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9984 - loss: 0.0088 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9981 - loss: 0.0111 - val_accuracy: 0.9995 - val_loss: 0.0042
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9984 - loss: 0.0085 - val_accuracy: 0.9992 - val_loss: 0.0045
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9989 - loss: 0.0074
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9993 - loss: 0.0046
# Fold 1 - Training Loss: 0.004707928281277418, Training Accuracy: 0.9993524551391602
# Fold 1 - Validation Loss: 0.0039331866428256035, Validation Accuracy: 0.9994701743125916
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1873
#            1       1.00      1.00      1.00      1902
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------

# %%
# Calculate and print the mean and standard deviation of training accuracy and loss across folds
mean_train_accuracy = sum(train_accuracies_static) / num_folds
std_train_accuracy = (sum([(acc - mean_train_accuracy) ** 2 for acc in train_accuracies_static]) / num_folds) ** 0.5
mean_train_loss = sum(train_losses_static) / num_folds
std_train_loss = (sum([(loss - mean_train_loss) ** 2 for loss in train_losses_static]) / num_folds) ** 0.5
print(f"Mean Training Accuracy: {mean_train_accuracy}, Std Training Accuracy: {std_train_accuracy}")
print(f"Mean Training Loss: {mean_train_loss}, Std Training Loss: {std_train_loss}")

# Calculate and print the mean and standard deviation of validation accuracy and loss across folds
mean_val_accuracy = sum(val_accuracies_static) / num_folds
std_val_accuracy = (sum([(acc - mean_val_accuracy) ** 2 for acc in val_accuracies_static]) / num_folds) ** 0.5
mean_val_loss = sum(val_losses_static) / num_folds
std_val_loss = (sum([(loss - mean_val_loss) ** 2 for loss in val_losses_static]) / num_folds) ** 0.5
print(f"Mean Validation Accuracy: {mean_val_accuracy}, Std Validation Accuracy: {std_val_accuracy}")
print(f"Mean Validation Loss: {mean_val_loss}, Std Validation Loss: {std_val_loss}")
# Out:
# Mean Training Accuracy: 0.9993612885475158, Std Training Accuracy: 4.7547225513782755e-05
# Mean Training Loss: 0.004544517491012812, Std Training Loss: 0.0003416324655327869
# Mean Validation Accuracy: 0.9993642330169678, Std Validation Accuracy: 0.0003964716992852376
# Mean Validation Loss: 0.004472855245694518, Std Validation Loss: 0.0025834537759921203

# %%
avg_report = {
    'Class 0': {
        'precision': np.mean([r['0']['precision'] for r in classification_reports]),
        'recall': np.mean([r['0']['recall'] for r in classification_reports]),
        'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports]),
        'support': np.sum([r['0']['support'] for r in classification_reports])
    },
    'Class 1': {
        'precision': np.mean([r['1']['precision'] for r in classification_reports]),
        'recall': np.mean([r['1']['recall'] for r in classification_reports]),
        'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports]),
        'support': np.sum([r['1']['support'] for r in classification_reports])
    }
}

# Print the aggregated classification report
print("Average Classification Report across all folds:")
print(avg_report)
# Out:
# Average Classification Report across all folds:
# {'Class 0': {'precision': np.float64(1.0), 'recall': np.float64(0.9987234248859126), 'f1-score': np.float64(0.9993611427719149), 'support': np.float64(18875.0)}, 'Class 1': {'precision': np.float64(0.9987352923500525), 'recall': np.float64(1.0), 'f1-score': np.float64(0.999367093800204), 'support': np.float64(18875.0)}}

# %%
print(history_static_kmeans.history.keys())
num_epochs = len(history_static_kmeans.history['loss'])
print(f"Number of epochs: {num_epochs}")
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Number of epochs: 8

# %%
import csv

# Define the file name for saving the metrics
csv_file = 'metrics_CNN_KmeansSMOTE.csv'

# Define headers for training and validation metrics

headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']

# Combine training and validation metrics into a single list
all_metrics = []

num_epochs = len(history_static_kmeans.history['loss'])
print(f"Number of epochs: {num_epochs}")

# Collect the metrics and populate the data
for epoch in range(num_epochs):
    # Training metrics for the current epoch
    train_loss = history_static_kmeans.history['loss'][epoch]
    train_accuracy = history_static_kmeans.history['accuracy'][epoch]

    # Validation metrics for the current epoch
    val_loss = history_static_kmeans.history['val_loss'][epoch]
    val_accuracy = history_static_kmeans.history['val_accuracy'][epoch]

    # Append the metrics for the current epoch
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

# Write the metrics to a CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the headers
    writer.writerow(headers)

    # Write the data
    writer.writerows(all_metrics)
# Out:
# Number of epochs: 8

# %%
all_metrics
# Out:
# [[1, 0.009866601787507534, 0.9980868101119995, 0.0014649891527369618, 1.0],
#  [2, 0.009759406559169292, 0.9979985356330872, 0.0009211119613610208, 1.0],
#  [3, 0.00905750971287489, 0.9981456995010376, 0.001259676064364612, 1.0],
#  [4, 0.010628641583025455, 0.9980573654174805, 0.0004862740752287209, 1.0],
#  [5, 0.00932395365089178, 0.9981162548065186, 0.0002276339364470914, 1.0],
#  [6, 0.008713537827134132, 0.9984694719314575, 0.0011178831337019801, 1.0],
#  [7, 0.008478266187012196, 0.9983811378479004, 0.0003843010345008224, 1.0],
#  [8, 0.009148314595222473, 0.9983811378479004, 0.0004255824023857713, 1.0]]

# %%
# print(f"x_test_padded1 shape: {x_test_padded1.shape}")
# print(f"y_test1 shape: {y_test1.shape}")

# %% [markdown]
# ####Testing

# %%
# Evaluate the static model
static_evaluation1 = static_model.evaluate(x_test_padded1, y_test1, batch_size=32)
static_accuracy1 = static_evaluation1[1]

print("Static Model Evaluation Results:")
print("Accuracy:", static_accuracy1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9700 - loss: 0.0881
# Static Model Evaluation Results:
# Accuracy: 0.9736483693122864

# %%
y_test_pred1 = (static_model.predict(x_test_padded1) > 0.5).astype("int32").flatten()

test_report1 = classification_report(y_test1, y_test_pred1)

print("Classification Report on Test Dataset 1 :")
print(test_report1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Classification Report on Test Dataset 1 :
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2097
#            1       0.65      0.94      0.77       104
#
#     accuracy                           0.97      2201
#    macro avg       0.83      0.96      0.88      2201
# weighted avg       0.98      0.97      0.98      2201

# %%
# Run garbage collection
gc.collect()
# Out:
# 18044

# %% [markdown]
# ###CNN SVMSMOTE Train and Test

# %%
# Create the static model
static_model = Model(inputs=static_input, outputs=output)
static_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the static model
epochs_static = 10
history_static_svm = static_model.fit(
    x_train_resampled_svm,
    y_train_resampled_svm,
    batch_size=32,
    epochs=epochs_static,
    validation_split=0.1,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9984 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9987 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9982 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9986 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 6.1101e-04
# Epoch 5/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9988 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 2.5650e-04
# Epoch 6/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9988 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 7.0917e-04
# Epoch 7/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9986 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 6.9624e-04
# Epoch 8/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9986 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 5.9793e-04

# %% [markdown]
# ####Cross-Validation Train

# %%
from sklearn.model_selection import KFold
# Define the number of folds
num_folds = 10

# Initialize K-Fold cross-validator
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)  # You can set a random seed for reproducibility

# Initialize lists to store cross-validation results
accuracies = []
losses = []

# %%
# Convert the data to numpy arrays
x_train_np = np.array(x_train_resampled_svm)
y_train_np = np.array(y_train_resampled_svm)

# %%
# Initialize lists to store training and validation accuracies and losses
train_accuracies_static = []
val_accuracies_static = []
train_losses_static = []
val_losses_static = []
classification_reports = []
# Iterate over the folds
fold = 0
for train_indices, val_indices in kf.split(x_train_np):
    fold += 1
    print(f"Training fold {fold}/{num_folds}")

    static_model = Model(inputs=static_input, outputs=output)

    static_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # Get the training and validation data for this fold
    x_train_fold = x_train_np[train_indices]
    y_train_fold = y_train_np[train_indices]
    x_val_fold = x_train_np[val_indices]
    y_val_fold = y_train_np[val_indices]

    # Early stopping callback
    early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

    # Train the model for this fold
    static = static_model.fit(
        x_train_fold,
        y_train_fold,
        batch_size=32,
        epochs=epochs_static,  # Make sure you define epochs_hybrid
        validation_data=(x_val_fold, y_val_fold),
        callbacks=[early_stopping],
    )

    # Evaluate the model on this fold for training and validation
    train_loss_static, train_accuracy_static = static_model.evaluate(x_train_fold, y_train_fold)
    val_loss_static, val_accuracy_static = static_model.evaluate(x_val_fold, y_val_fold)

    print(f"Fold {fold} - Training Loss: {train_loss_static}, Training Accuracy: {train_accuracy_static}")
    print(f"Fold {fold} - Validation Loss: {val_loss_static}, Validation Accuracy: {val_accuracy_static}")

    # Store the results for this fold
    train_accuracies_static.append(train_accuracy_static)
    val_accuracies_static.append(val_accuracy_static)
    train_losses_static.append(train_loss_static)
    val_losses_static.append(val_loss_static)

    # Evaluate the model
    y_pred = (static_model.predict(x_val_fold) > 0.5).astype("int32").flatten()

    # Generate and store the classification report
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports.append(report)

    # Print the classification report for this fold
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)
# Out:
# Training fold 1/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9984 - loss: 0.0102 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9980 - loss: 0.0118 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9984 - loss: 0.0094 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9988 - loss: 0.0072 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 5/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9987 - loss: 0.0081 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 6/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9986 - loss: 0.0074 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 7/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9987 - loss: 0.0074 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 8/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9981 - loss: 0.0120 - val_accuracy: 0.9995 - val_loss: 0.0041
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9989 - loss: 0.0069
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9993 - loss: 0.0043
# Fold 1 - Training Loss: 0.004518721252679825, Training Accuracy: 0.9993524551391602
# Fold 1 - Validation Loss: 0.0037963399663567543, Validation Accuracy: 0.9994701743125916
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1884
#            1       1.00      1.00      1.00      1891
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 2/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9985 - loss: 0.0087 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9989 - loss: 0.0059 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9982 - loss: 0.0093 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9984 - loss: 0.0086 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 5/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9980 - loss: 0.0115 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 6/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9988 - loss: 0.0074 - val_accuracy: 0.9995 - val_loss: 0.0038
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9990 - loss: 0.0063
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9983 - loss: 0.0109
# Fold 2 - Training Loss: 0.004531318321824074, Training Accuracy: 0.9993524551391602
# Fold 2 - Validation Loss: 0.0037533296272158623, Validation Accuracy: 0.9994701743125916
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1895
#            1       1.00      1.00      1.00      1880
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 3/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9980 - loss: 0.0101 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9988 - loss: 0.0069 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9989 - loss: 0.0075
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9998 - loss: 0.0015
# Fold 8 - Training Loss: 0.00479771476238966, Training Accuracy: 0.9993230104446411
# Fold 8 - Validation Loss: 0.002067345194518566, Validation Accuracy: 0.9997351169586182
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1907
#            1       1.00      1.00      1.00      1868
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 9/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9983 - loss: 0.0105 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9982 - loss: 0.0095 - val_accuracy: 0.9997 - val_loss: 0.0024
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9984 - loss: 0.0095 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9990 - loss: 0.0076 - val_accuracy: 0.9997 - val_loss: 0.0021
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9989 - loss: 0.0074
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9996 - loss: 0.0026
# Fold 9 - Training Loss: 0.004836120177060366, Training Accuracy: 0.9993230104446411
# Fold 9 - Validation Loss: 0.0020562177523970604, Validation Accuracy: 0.9997351169586182
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1930
#            1       1.00      1.00      1.00      1845
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 10/10
# Epoch 1/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9990 - loss: 0.0074 - val_accuracy: 0.9992 - val_loss: 0.0060
# Epoch 2/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9982 - loss: 0.0098 - val_accuracy: 0.9992 - val_loss: 0.0057
# Epoch 3/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 27ms/step - accuracy: 0.9983 - loss: 0.0085 - val_accuracy: 0.9992 - val_loss: 0.0060
# Epoch 4/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9990 - loss: 0.0062 - val_accuracy: 0.9992 - val_loss: 0.0057
# Epoch 5/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9987 - loss: 0.0067 - val_accuracy: 0.9992 - val_loss: 0.0055
# Epoch 6/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9986 - loss: 0.0090 - val_accuracy: 0.9992 - val_loss: 0.0058
# Epoch 7/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9986 - loss: 0.0068 - val_accuracy: 0.9992 - val_loss: 0.0063
# Epoch 8/10
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.9984 - loss: 0.0101 - val_accuracy: 0.9992 - val_loss: 0.0059
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9990 - loss: 0.0064
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9987 - loss: 0.0087
# Fold 10 - Training Loss: 0.004354620818048716, Training Accuracy: 0.9993818998336792
# Fold 10 - Validation Loss: 0.005491630639880896, Validation Accuracy: 0.9992052912712097
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1873
#            1       1.00      1.00      1.00      1902
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------

# %%
# Calculate and print the mean and standard deviation of training accuracy and loss across folds
mean_train_accuracy = sum(train_accuracies_static) / num_folds
std_train_accuracy = (sum([(acc - mean_train_accuracy) ** 2 for acc in train_accuracies_static]) / num_folds) ** 0.5
mean_train_loss = sum(train_losses_static) / num_folds
std_train_loss = (sum([(loss - mean_train_loss) ** 2 for loss in train_losses_static]) / num_folds) ** 0.5
print(f"Mean Training Accuracy: {mean_train_accuracy}, Std Training Accuracy: {std_train_accuracy}")
print(f"Mean Training Loss: {mean_train_loss}, Std Training Loss: {std_train_loss}")

# Calculate and print the mean and standard deviation of validation accuracy and loss across folds
mean_val_accuracy = sum(val_accuracies_static) / num_folds
std_val_accuracy = (sum([(acc - mean_val_accuracy) ** 2 for acc in val_accuracies_static]) / num_folds) ** 0.5
mean_val_loss = sum(val_losses_static) / num_folds
std_val_loss = (sum([(loss - mean_val_loss) ** 2 for loss in val_losses_static]) / num_folds) ** 0.5
print(f"Mean Validation Accuracy: {mean_val_accuracy}, Std Validation Accuracy: {std_val_accuracy}")
print(f"Mean Validation Loss: {mean_val_loss}, Std Validation Loss: {std_val_loss}")
# Out:
# Mean Training Accuracy: 0.9993642270565033, Std Training Accuracy: 4.4054447785203437e-05
# Mean Training Loss: 0.004447190486826002, Std Training Loss: 0.0003038712268521578
# Mean Validation Accuracy: 0.9993642330169678, Std Validation Accuracy: 0.0003964716992852376
# Mean Validation Loss: 0.004412449314258993, Std Validation Loss: 0.0024617651774586527

# %%
avg_report = {
    'Class 0': {
        'precision': np.mean([r['0']['precision'] for r in classification_reports]),
        'recall': np.mean([r['0']['recall'] for r in classification_reports]),
        'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports]),
        'support': np.sum([r['0']['support'] for r in classification_reports])
    },
    'Class 1': {
        'precision': np.mean([r['1']['precision'] for r in classification_reports]),
        'recall': np.mean([r['1']['recall'] for r in classification_reports]),
        'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports]),
        'support': np.sum([r['1']['support'] for r in classification_reports])
    }
}

# Print the aggregated classification report
print("Average Classification Report across all folds:")
print(avg_report)
# Out:
# Average Classification Report across all folds:
# {'Class 0': {'precision': np.float64(1.0), 'recall': np.float64(0.9987234248859126), 'f1-score': np.float64(0.9993611427719149), 'support': np.float64(18875.0)}, 'Class 1': {'precision': np.float64(0.9987352923500525), 'recall': np.float64(1.0), 'f1-score': np.float64(0.999367093800204), 'support': np.float64(18875.0)}}

# %%
print(history_static_svm.history.keys())
num_epochs = len(history_static_svm.history['loss'])
print(f"Number of epochs: {num_epochs}")
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Number of epochs: 8

# %%
import csv

# Define the file name for saving the metrics
csv_file = 'metrics_CNN_SVMSMOTE.csv'

# Define headers for training and validation metrics

headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']

# Combine training and validation metrics into a single list
all_metrics = []

num_epochs = len(history_static_svm.history['loss'])
print(f"Number of epochs: {num_epochs}")

# Collect the metrics and populate the data
for epoch in range(num_epochs):
    # Training metrics for the current epoch
    train_loss = history_static_svm.history['loss'][epoch]
    train_accuracy = history_static_svm.history['accuracy'][epoch]

    # Validation metrics for the current epoch
    val_loss = history_static_svm.history['val_loss'][epoch]
    val_accuracy = history_static_svm.history['val_accuracy'][epoch]

    # Append the metrics for the current epoch
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

# Write the metrics to a CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the headers
    writer.writerow(headers)

    # Write the data
    writer.writerows(all_metrics)
# Out:
# Number of epochs: 8

# %%
all_metrics
# Out:
# [[1, 0.00828575249761343, 0.9985577464103699, 0.001407691859640181, 1.0],
#  [2, 0.008382171392440796, 0.998646080493927, 0.0011782944202423096, 1.0],
#  [3, 0.009256972931325436, 0.9983811378479004, 0.0011973585933446884, 1.0],
#  [4, 0.007919973693788052, 0.9985871911048889, 0.0006110110552981496, 1.0],
#  [5, 0.006604000926017761, 0.9989109635353088, 0.0002565019531175494, 1.0],
#  [6, 0.008036582730710506, 0.9985871911048889, 0.0007091705338098109, 1.0],
#  [7, 0.008321460336446762, 0.9985283017158508, 0.0006962443585507572, 1.0],
#  [8, 0.00822689849883318, 0.9985871911048889, 0.0005979316192679107, 1.0]]

# %% [markdown]
# ####Testing

# %%
# Evaluate the static model
static_evaluation1 = static_model.evaluate(x_test_padded1, y_test1, batch_size=32)
static_accuracy1 = static_evaluation1[1]

print("Static Model Evaluation Results:")
print("Accuracy:", static_accuracy1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9673 - loss: 0.1210
# Static Model Evaluation Results:
# Accuracy: 0.9722853302955627

# %%
y_test_pred1 = (static_model.predict(x_test_padded1) > 0.5).astype("int32").flatten()

test_report1 = classification_report(y_test1, y_test_pred1)

print("Classification Report on Test Dataset 1 :")
print(test_report1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Classification Report on Test Dataset 1 :
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99      2097
#            1       0.64      0.95      0.76       104
#
#     accuracy                           0.97      2201
#    macro avg       0.82      0.96      0.87      2201
# weighted avg       0.98      0.97      0.97      2201

# %% [markdown]
# ##Evaluation

# %%
torch.cuda.empty_cache()

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.model_selection import KFold
import seaborn as sns
import matplotlib.pyplot as plt

def show_confusion_matrix(confusion_matrix):
        hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
        hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
        hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')

        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')

# %% [markdown]
# ###CNN

# %% [markdown]
# ####BorderlineSMOTE

# %%
import matplotlib.pyplot as plt
train_loss_static = history_static.history['loss']
val_loss_static = history_static.history['val_loss']
# Plot the loss curves
plt.plot(range(1, len(train_loss_static) + 1), train_loss_static, label='Training Loss')
plt.plot(range(1, len(val_loss_static) + 1), val_loss_static, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss CNN')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
accuracy_static = history_static.history['accuracy']
val_accuracy_static = history_static.history['val_accuracy']
# Plot the loss curves
plt.plot(range(1, len(accuracy_static) + 1), accuracy_static, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy_static) + 1), val_accuracy_static, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy CNN')
plt.legend()
plt.show()

# %%
predictions_static_1 = static_model.predict(x_test_padded1)
predicted_labels_static_1 = (predictions_static_1 > 0.5).astype(int)
cm_static_1 = confusion_matrix(y_test1,predicted_labels_static_1)
show_confusion_matrix(cm_static_1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %% [markdown]
# ####KMeansSMOTE

# %%
import matplotlib.pyplot as plt
train_loss_static = history_static_kmeans.history['loss']
val_loss_static = history_static_kmeans.history['val_loss']
# Plot the loss curves
plt.plot(range(1, len(train_loss_static) + 1), train_loss_static, label='Training Loss')
plt.plot(range(1, len(val_loss_static) + 1), val_loss_static, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss CNN')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
accuracy_static = history_static_kmeans.history['accuracy']
val_accuracy_static = history_static_kmeans.history['val_accuracy']
# Plot the loss curves
plt.plot(range(1, len(accuracy_static) + 1), accuracy_static, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy_static) + 1), val_accuracy_static, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy CNN')
plt.legend()
plt.show()

# %%
predictions_static_1 = static_model.predict(x_test_padded1)
predicted_labels_static_1 = (predictions_static_1 > 0.5).astype(int)
cm_static_1 = confusion_matrix(y_test1,predicted_labels_static_1)
show_confusion_matrix(cm_static_1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %% [markdown]
# ####SVMSMOTE

# %%
import matplotlib.pyplot as plt
train_loss_static = history_static_svm.history['loss']
val_loss_static = history_static_svm.history['val_loss']
# Plot the loss curves
plt.plot(range(1, len(train_loss_static) + 1), train_loss_static, label='Training Loss')
plt.plot(range(1, len(val_loss_static) + 1), val_loss_static, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss CNN')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
accuracy_static = history_static_svm.history['accuracy']
val_accuracy_static = history_static_svm.history['val_accuracy']
# Plot the loss curves
plt.plot(range(1, len(accuracy_static) + 1), accuracy_static, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy_static) + 1), val_accuracy_static, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy CNN')
plt.legend()
plt.show()

# %%
predictions_static_1 = static_model.predict(x_test_padded1)
predicted_labels_static_1 = (predictions_static_1 > 0.5).astype(int)
cm_static_1 = confusion_matrix(y_test1,predicted_labels_static_1)
show_confusion_matrix(cm_static_1)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
