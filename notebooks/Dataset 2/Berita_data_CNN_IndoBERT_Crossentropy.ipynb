# %% [markdown]
# ###Installing Library

# %%
# !pip install -q torch
# !pip install -q tf
# !pip install -q gdown
# !pip install -q transformers[torch] accelerate -U
# !pip install -q accelerate -U
# !pip install -q datasets
# !pip install -q gensim
# !pip install -q evaluate
# !pip install -q imblearn
# !pip install -q tensorflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 88.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.9 MB/s eta 0:00:00

# %% [markdown]
# ###Import Library

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import re
import gc
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report
from collections import Counter
import tensorflow as tf
from gensim.models import Word2Vec
from transformers import AutoTokenizer, AutoModelForSequenceClassification,Trainer, AutoConfig, TrainingArguments, EarlyStoppingCallback
from tensorflow.keras.layers import Input, Embedding, Conv1D, GlobalMaxPooling1D, MaxPooling1D, Dense, Flatten, concatenate, BatchNormalization,LSTM, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import backend as K
from evaluate import load as load_metric
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import he_normal
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import BorderlineSMOTE,KMeansSMOTE,SVMSMOTE
import os
os.environ["WANDB_DISABLED"] = "true"
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import Dataset

# %% [markdown]
# ###Read Dataset and load Word2Vec

# %%
df = pd.read_csv("/content/news_train_balanced_clean.csv")

# %%
df_test1 = pd.read_csv("/content/news_test_clean.csv")
# # df_test2 = pd.read_csv("test_data_2.csv")
# # df_test3 = pd.read_csv("test_data_3.csv")

# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
gc.collect()
print(gensim.__version__)
# Load Pretrained Word Embeddings (Word2Vec)
# !gdown --id 1QYj5FruufaPq2mZgC6lZlq2Uw2E004Og
# !gdown --id 1F9QsHO7FPIPq3nL_I0zCkZFvq3OVcJrB
# !gdown --id 1VUjxpH10baOw439V-YAAVVbtyI8iLgG5
# Out:
# 4.4.0

# %%
import os
import gdown
import zipfile

'''https://drive.google.com/file/d/1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3/view?usp=sharing'''

file_id = '1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3'

url = f'https://drive.google.com/uc?id={file_id}'
output_zip = 'model_w2v.zip'

if not os.path.exists('idwiki_word2vec_768_new_lower.model'):
    print("Downloading Model...")
    gdown.download(url, output_zip, quiet=False)

    print("Extracting File...")
    with zipfile.ZipFile(output_zip, 'r') as zip_ref:
        zip_ref.extractall('/content/')
    print("Done.")
else:
    print("Model Available")
# Out:
# Downloading Model...
# Downloading...
# From (original): https://drive.google.com/uc?id=1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3
# From (redirected): https://drive.google.com/uc?id=1R0Rq2oQEH4N1K7eXLvGkvKosR2rzxIw3&confirm=t&uuid=69d5998d-4b2f-4283-a7d4-a915db0514e0
# To: /content/model_w2v.zip
# 100%|██████████| 2.56G/2.56G [00:32<00:00, 78.9MB/s]
# Extracting File...
# Done.

# %%
word_embeddings = Word2Vec.load('/content/idwiki_word2vec_768_new_lower.model')
#word_embeddings = Word2Vec.load('/content/modelword2vec/idwiki_word2vec_768_new_lower.model')

# %% [markdown]
# ###Split Dataset

# %%
x_train = df['Text'].astype(str)
y_train = df['Label']

# %%
x_test1 = df_test1['Text'].astype(str)
y_test1 = np.array(df_test1['Label'])

# %%
# x_test2 = df_test2['Text']
# y_test2 = np.array(df_test2['Label'])

# %%
# x_test3 = df_test3['Text']
# y_test3 = np.array(df_test3['Label'])

# %% [markdown]
# ###Define Loss Function, Tokenization, Word Embeddings and Oversampling

# %%
# # # Define the margin loss function
# def margin_loss(y_true, y_pred):
#     margin = K.constant(0.1)
#     y_true_float = K.cast(y_true, dtype='float32')  # Convert y_true to float32
#     squared_difference_pos = K.square(K.maximum(0.9 - y_pred, 0))
#     squared_difference_neg = K.square(K.maximum(y_pred - 0.1, 0))
#     loss_pos = K.mean(y_true_float * squared_difference_pos)
#     loss_neg = K.mean((1 - y_true_float) * squared_difference_neg)
#     total_loss = loss_pos + lambda_val * loss_neg
#     return total_loss

# %%
# Define the model architectures
#max_sequence_length = 100
# lambda_val = 0.7  # Lambda value for margin loss
num_words = 100000
embedding_dim = word_embeddings.vector_size
features_logits_count = 2 # Define features_logits_count here based on the output shape of IndoBERT (2 classes)

# %%
# Tokenization
tokenizer = Tokenizer(num_words=num_words, oov_token='<OOV>')
tokenizer.fit_on_texts(x_train)

# Convert text to sequences and pad
x_train_sequences = tokenizer.texts_to_sequences(x_train)
x_test_sequences1 = tokenizer.texts_to_sequences(x_test1)
# x_test_sequences2 = tokenizer.texts_to_sequences(x_test2)
# x_test_sequences3 = tokenizer.texts_to_sequences(x_test3)

# Determine max sequence length based on your data
max_sequence_length = max(max(len(seq) for seq in x_train_sequences), max(len(seq) for seq in x_test_sequences1))

x_train_padded = pad_sequences(x_train_sequences, maxlen=max_sequence_length, padding='post')
x_test_padded1 = pad_sequences(x_test_sequences1, maxlen=max_sequence_length, padding='post')
# x_test_padded2 = pad_sequences(x_test_sequences2, maxlen=max_sequence_length, padding='post')
# x_test_padded3 = pad_sequences(x_test_sequences3, maxlen=max_sequence_length, padding='post')

# %%
# Create word index
word_index_keras = tokenizer.word_index
print(f"Full vocabulary size (Word2Vec): {len(word_embeddings.wv.index_to_key)}")
print(f"Tokenizer vocabulary size (Top K): {len(word_index_keras)}")
# Out:
# Full vocabulary size (Word2Vec): 447356
# Tokenizer vocabulary size (Top K): 85374

# %%
# Create embedding matrix
vocab_size = min(len(word_index_keras) + 1, num_words)

embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in word_index_keras.items():
    if i >= vocab_size:
        continue
    if word in word_embeddings.wv:
        embedding_vector = word_embeddings.wv[word]
        embedding_matrix[i] = embedding_vector

print(f"Shape of embedding matrix: {embedding_matrix.shape}")
# Out:
# Shape of embedding matrix: (85375, 768)

# %%
print(f"Input shape: {x_train_padded.shape}")
# Out:
# Input shape: (37750, 3690)

# %% [markdown]
# ####Oversampling with BorderlineSMOTE

# %%
borderline_smote = BorderlineSMOTE(random_state=42)
x_train_flat = x_train_padded.reshape(x_train_padded.shape[0], -1) # Flatten x_train_padded
x_train_resampled_flat_borderline, y_train_resampled_borderline = borderline_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_borderline = x_train_resampled_flat_borderline.reshape(x_train_resampled_flat_borderline.shape[0], max_sequence_length)

# %% [markdown]
# ####Oversampling with KMeansSMOTE

# %%
kmeans_smote = KMeansSMOTE(random_state=42, cluster_balance_threshold=0.2)
x_train_resampled_flat_kmeans, y_train_resampled_kmeans = kmeans_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_kmeans = x_train_resampled_flat_kmeans.reshape(x_train_resampled_flat_kmeans.shape[0], max_sequence_length)

# %% [markdown]
# ####Oversampling with SVMSMOTE

# %%
svm_smote = SVMSMOTE(random_state=42)
x_train_resampled_flat_svm, y_train_resampled_svm = svm_smote.fit_resample(x_train_flat, y_train)
x_train_resampled_svm = x_train_resampled_flat_svm.reshape(x_train_resampled_flat_svm.shape[0], max_sequence_length)

# %%
torch.cuda.empty_cache()
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ##CNN + IndoBERT Model

# %% [markdown]
# ###Preparing Model

# %% [markdown]
# ####Load IndoBERT

# %%
from datasets import load_dataset, Dataset

df_train_bert, df_eval_bert = train_test_split(df, test_size=0.1, random_state=42, stratify=df['Label'])

df_train_bert.to_csv("bert_train.csv", index=False)
df_eval_bert.to_csv("bert_eval.csv", index=False)

bert_files = {"train": "bert_train.csv", "eval": "bert_eval.csv"}
bert_dataset = load_dataset('csv', data_files=bert_files)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]

# %%
# Load Model dan Tokenizer IndoBERT
with torch.no_grad():
    indobert_model = "indobenchmark/indobert-base-p2"
    tokenizer = AutoTokenizer.from_pretrained(indobert_model)
    config = AutoConfig.from_pretrained(indobert_model, num_labels=2)
    model_indoBERT = AutoModelForSequenceClassification.from_pretrained(indobert_model, config=config)
    model_indoBERT.to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-base-p2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Tokenization
def tokenizer_transformer(text):
    text_to_tokenize = [str(item) for item in text["Text"]]
    encoding = tokenizer(text_to_tokenize, padding='max_length', max_length=256, truncation=True)
    encoding['labels'] = text['Label']
    return encoding

tokenized_bert_datasets = bert_dataset.map(tokenizer_transformer, batched=True)
# Out:
# Map:   0%|          | 0/33975 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3775 [00:00<?, ? examples/s]

# %%
# Fine-Tuning IndoBERT
training_args = TrainingArguments(
    "transformer_trainer",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    weight_decay=0.01,
    load_best_model_at_end=True,
    greater_is_better=False,
    num_train_epochs=3,
    fp16=True,
    report_to="none",
    dataloader_num_workers=4
)

# %%
metrics = load_metric("accuracy")
def processing_metric(pred):
    logits, labels = pred
    predictions = np.argmax(logits, axis=-1)
    return metrics.compute(predictions=predictions, references=labels)

early_stopping_bert = EarlyStoppingCallback(early_stopping_patience=3, early_stopping_threshold=0.01)

non_static_trainer = Trainer(
    model=model_indoBERT,
    args=training_args,
    train_dataset=tokenized_bert_datasets["train"],
    eval_dataset=tokenized_bert_datasets["eval"],
    tokenizer=tokenizer,
    compute_metrics=processing_metric,
    callbacks=[early_stopping_bert]
)

non_static_trainer.train()
# Out:
# /tmp/ipython-input-3455666978.py:9: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   non_static_trainer = Trainer(
#     <div>
#
#       <progress value='1593' max='1593' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1593/1593 11:09, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.028300</td>
#       <td>0.002966</td>
#       <td>0.999735</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.006100</td>
#       <td>0.003969</td>
#       <td>0.999735</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.005000</td>
#       <td>0.003371</td>
#       <td>0.999735</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1593, training_loss=0.012691173176307463, metrics={'train_runtime': 669.91, 'train_samples_per_second': 152.147, 'train_steps_per_second': 2.378, 'total_flos': 1.3408797158784e+16, 'train_loss': 0.012691173176307463, 'epoch': 3.0})

# %%
# Logits x_train
df_full_train = pd.DataFrame({'Text': x_train, 'Label': y_train})
dataset_full_train = Dataset.from_pandas(df_full_train)

# Tokenisasi dataset
tokenized_full_dataset = dataset_full_train.map(tokenizer_transformer, batched=True)
tokenized_full_dataset.set_format(type='torch', columns=['input_ids', 'token_type_ids', 'attention_mask', 'labels'])

predictions = non_static_trainer.predict(tokenized_full_dataset)
non_static_logits_train = predictions.predictions
print(f"Logits Shape: {non_static_logits_train.shape}")
# Out:
# Map:   0%|          | 0/37750 [00:00<?, ? examples/s]
# Logits Shape: (37750, 2)

# %%
# Logits x_test
df_full_test1 = pd.DataFrame({'Text': x_test1, 'Label': y_test1})
dataset_full_test1 = Dataset.from_pandas(df_full_test1)

# Tokenization x_test
tokenized_full_test1_dataset = dataset_full_test1.map(tokenizer_transformer, batched=True)
tokenized_full_test1_dataset.set_format(type='torch', columns=['input_ids', 'token_type_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/2201 [00:00<?, ? examples/s]

# %%
predictions_test1 = non_static_trainer.predict(tokenized_full_test1_dataset)
non_static_logits_test1 = predictions_test1.predictions
print(f"Logits Test 1 Shape: {non_static_logits_test1.shape}")
# Out:
# Logits Test 1 Shape: (2201, 2)

# %%
del model_indoBERT, non_static_trainer
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ####SMOTE

# %%
# Flatten Input
x_train_padded_flat = x_train_padded.reshape(x_train_padded.shape[0], -1)
x_train_padded_flat = x_train_padded.reshape(x_train_padded.shape[0], -1)

x_train_combined = np.concatenate([x_train_padded_flat, non_static_logits_train], axis=1)
y_train_combined = y_train
print(f"{x_train_combined.shape}")
# Out:
# (37750, 3692)

# %%
features_padded_flat_count = x_train_padded_flat.shape[1]
features_logits_count = non_static_logits_train.shape[1]

# %%
# Oversampling BorderlineSMOTE
borderline_smote = BorderlineSMOTE(random_state=42)
x_res_comb_border, y_res_border = borderline_smote.fit_resample(x_train_combined, y_train_combined)

# Pisahkan kembali fitur yang sudah di-resample
x_res_pad_flat_border = x_res_comb_border[:, :features_padded_flat_count]
x_res_log_border = x_res_comb_border[:, -features_logits_count:]

# Reshape kembali input CNN
x_res_pad_border = x_res_pad_flat_border.reshape(-1, max_sequence_length)
print(f"BorderlineSMOTE padded shape: {x_res_pad_border.shape}")
print(f"BorderlineSMOTE logits shape: {x_res_log_border.shape}")
print(f"BorderlineSMOTE labels shape: {y_res_border.shape}")
# Out:
# BorderlineSMOTE padded shape: (37750, 3690)
# BorderlineSMOTE logits shape: (37750, 2)
# BorderlineSMOTE labels shape: (37750,)

# %%
# Oversampling KMeansSMOTE
kmeans_smote = KMeansSMOTE(random_state=42, cluster_balance_threshold=0.2)
x_res_comb_kmeans, y_res_kmeans = kmeans_smote.fit_resample(x_train_combined, y_train_combined)

x_res_pad_flat_kmeans = x_res_comb_kmeans[:, :features_padded_flat_count]
x_res_log_kmeans = x_res_comb_kmeans[:, -features_logits_count:]
x_res_pad_kmeans = x_res_pad_flat_kmeans.reshape(-1, max_sequence_length)
print(f"KMeansSMOTE padded shape: {x_res_pad_kmeans.shape}")
# Out:
# KMeansSMOTE padded shape: (37750, 3690)

# %%
# Oversampling SVMSMOTE
svm_smote = SVMSMOTE(random_state=42)
x_res_comb_svm, y_res_svm = svm_smote.fit_resample(x_train_combined, y_train_combined)

# Pisahkan kembali
x_res_pad_flat_svm = x_res_comb_svm[:, :features_padded_flat_count]
x_res_log_svm = x_res_comb_svm[:, -features_logits_count:]
x_res_pad_svm = x_res_pad_flat_svm.reshape(-1, max_sequence_length)
print(f"SVMSMOTE padded shape: {x_res_pad_svm.shape}")
# Out:
# SVMSMOTE padded shape: (37750, 3690)

# %%
del x_train_combined, x_train_padded_flat
gc.collect()
# Out:
# 0

# %% [markdown]
# ####CNN + IndoBERT

# %%
#Define Multichannel Model (CNN + IndoBERT Logits)
def create_multichannel_model():
    # CNN Branch
    static_input = Input(shape=(max_sequence_length,), name='static_input')

    static_embedding = Embedding(vocab_size,
                                 embedding_dim,
                                 weights=[embedding_matrix],
                                 input_length=max_sequence_length,
                                 trainable=False)(static_input)

    static_cnn_output = Conv1D(128, 3, activation='relu', kernel_initializer=he_normal())(static_embedding)
    static_cnn_output = MaxPooling1D(2)(static_cnn_output)
    static_cnn_output = GlobalMaxPooling1D()(static_cnn_output)
    static_cnn_output = Dropout(0.5)(static_cnn_output)
    batch_norm_layer = BatchNormalization()(static_cnn_output)

    # IndoBERT Logits Branch
    non_static_input = Input(shape=(features_logits_count,), name='non_static_input')

    # Concatenate
    combined_output = concatenate([batch_norm_layer, non_static_input])

    # Fully Connected Layers
    combined_dense = Dense(128, activation='relu', kernel_initializer=he_normal())(combined_output)
    combined_dense = Dropout(0.5)(combined_dense)
    output = Dense(1, activation='sigmoid')(combined_dense)

    model = Model(inputs=[static_input, non_static_input], outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

multichannel_model_summary = create_multichannel_model()
multichannel_model_summary.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ static_input        │ (None, 3690)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 3690, 768) │ 65,568,000 │ static_input[0][… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 3688, 128) │    295,040 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 1844, 128) │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ max_pooling1d[0]… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128)       │        512 │ dropout[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ non_static_input    │ (None, 2)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 130)       │          0 │ batch_normalizat… │
# │ (Concatenate)       │                   │            │ non_static_input… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     16,768 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 65,880,449 (251.31 MB)
#  Trainable params: 312,193 (1.19 MB)
#  Non-trainable params: 65,568,256 (250.12 MB)

# %%
del multichannel_model_summary
gc.collect()
# Out:
# 1485

# %%
early_stopping_keras = EarlyStopping(patience=3, restore_best_weights=True)
epochs = 10
num_folds = 10

# %% [markdown]
# ###CNN + IndoBERT BorderlineSMOTE Train

# %%
temp_model_border = create_multichannel_model()
history_borderline = temp_model_border.fit(
    [x_res_pad_border, x_res_log_border],
    y_res_border,
    batch_size=128,
    epochs=epochs,
    validation_split=0.1,
    callbacks=[early_stopping_keras],
)
# Out:
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 44s 127ms/step - accuracy: 0.9458 - loss: 0.1310 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 9.1320e-04
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 9.6107e-04
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 9.8238e-04
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0010

# %% [markdown]
# ####Cross-Validation Train

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
x_train_np_padded = np.array(x_res_pad_border)
x_train_np_logits = np.array(x_res_log_border)
y_train_np = np.array(y_res_border)

train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []
classification_reports_list = []

fold = 0
for train_indices, val_indices in kf.split(x_train_np_padded):
    fold += 1
    print(f"Training fold {fold}/{num_folds} (BorderlineSMOTE)")

    # Buat model baru untuk setiap fold
    model_fold = create_multichannel_model()

    # Ambil data fold
    x_train_fold_padded = x_train_np_padded[train_indices]
    x_train_fold_logits = x_train_np_logits[train_indices]
    y_train_fold = y_train_np[train_indices]

    x_val_fold_padded = x_train_np_padded[val_indices]
    x_val_fold_logits = x_train_np_logits[val_indices]
    y_val_fold = y_train_np[val_indices]

    # Train Model
    model_fold.fit(
        [x_train_fold_padded, x_train_fold_logits],
        y_train_fold,
        batch_size=128,
        epochs=epochs,
        validation_data=([x_val_fold_padded, x_val_fold_logits], y_val_fold),
        callbacks=[early_stopping_keras],
        verbose=1
    )

    # Evaluasi
    train_loss, train_accuracy = model_fold.evaluate([x_train_fold_padded, x_train_fold_logits], y_train_fold, verbose=0)
    val_loss, val_accuracy = model_fold.evaluate([x_val_fold_padded, x_val_fold_logits], y_val_fold, verbose=0)

    print(f"Fold {fold} - Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Fold {fold} - Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")

    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)
    train_losses.append(train_loss)
    val_losses.append(val_loss)

    # Classification Report
    y_pred = (model_fold.predict([x_val_fold_padded, x_val_fold_logits]) > 0.5).astype("int32").flatten()
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports_list.append(report)
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)

    del model_fold
    gc.collect()
# Out:
# Training fold 1/10 (BorderlineSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9002 - loss: 0.2236 - val_accuracy: 0.9995 - val_loss: 0.0043
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0086 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0072 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0067 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 92ms/step - accuracy: 0.9992 - loss: 0.0062 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0060 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0053 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9992 - loss: 0.0060 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0052 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0055 - val_accuracy: 0.9995 - val_loss: 0.0037
# Fold 1 - Train Loss: 0.0045, Train Acc: 0.9993
# Fold 1 - Val Loss: 0.0037, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1884
#            1       1.00      1.00      1.00      1891
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 2/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 103ms/step - accuracy: 0.9376 - loss: 0.1521 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0077 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0062 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0058 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0053 - val_accuracy: 0.9995 - val_loss: 0.0036
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0055 - val_accuracy: 0.9995 - val_loss: 0.0036
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0050 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0054 - val_accuracy: 0.9995 - val_loss: 0.0036
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0052 - val_accuracy: 0.9995 - val_loss: 0.0036
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0052 - val_accuracy: 0.9995 - val_loss: 0.0036
# Fold 2 - Train Loss: 0.0044, Train Acc: 0.9994
# Fold 2 - Val Loss: 0.0036, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1895
#            1       1.00      1.00      1.00      1880
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 3/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 103ms/step - accuracy: 0.9589 - loss: 0.1095 - val_accuracy: 0.9989 - val_loss: 0.0084
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0066 - val_accuracy: 0.9989 - val_loss: 0.0089
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9989 - val_loss: 0.0093
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0055 - val_accuracy: 0.9989 - val_loss: 0.0095
# Fold 3 - Train Loss: 0.0049, Train Acc: 0.9993
# Fold 3 - Val Loss: 0.0084, Val Acc: 0.9989
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1862
#            1       1.00      1.00      1.00      1913
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 4/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9532 - loss: 0.1215 - val_accuracy: 0.9995 - val_loss: 0.0043
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0080 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0065 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0062 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0062 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9992 - loss: 0.0057 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0053 - val_accuracy: 0.9995 - val_loss: 0.0039
# Fold 4 - Train Loss: 0.0047, Train Acc: 0.9994
# Fold 4 - Val Loss: 0.0039, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1933
#            1       1.00      1.00      1.00      1842
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 5/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9469 - loss: 0.1273 - val_accuracy: 0.9997 - val_loss: 0.0023
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9989 - loss: 0.0091 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0079 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0073 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0066 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0067 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0067 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0065 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0069 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0062 - val_accuracy: 0.9997 - val_loss: 0.0020
# Fold 5 - Train Loss: 0.0047, Train Acc: 0.9993
# Fold 5 - Val Loss: 0.0020, Val Acc: 0.9997
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1864
#            1       1.00      1.00      1.00      1911
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 6/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9157 - loss: 0.2119 - val_accuracy: 0.9989 - val_loss: 0.0081
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0077 - val_accuracy: 0.9989 - val_loss: 0.0078
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0058 - val_accuracy: 0.9989 - val_loss: 0.0077
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.9989 - val_loss: 0.0077
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0047 - val_accuracy: 0.9989 - val_loss: 0.0075
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0046 - val_accuracy: 0.9989 - val_loss: 0.0074
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0045 - val_accuracy: 0.9989 - val_loss: 0.0075
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9995 - loss: 0.0042 - val_accuracy: 0.9989 - val_loss: 0.0074
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9995 - loss: 0.0038 - val_accuracy: 0.9989 - val_loss: 0.0076
# Fold 6 - Train Loss: 0.0042, Train Acc: 0.9994
# Fold 6 - Val Loss: 0.0074, Val Acc: 0.9989
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1851
#            1       1.00      1.00      1.00      1924
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 7/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.8917 - loss: 0.2728 - val_accuracy: 0.9984 - val_loss: 0.0116
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0080 - val_accuracy: 0.9984 - val_loss: 0.0116
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0062 - val_accuracy: 0.9984 - val_loss: 0.0117
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0051 - val_accuracy: 0.9984 - val_loss: 0.0118
# Fold 7 - Train Loss: 0.0046, Train Acc: 0.9994
# Fold 7 - Val Loss: 0.0116, Val Acc: 0.9984
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1876
#            1       1.00      1.00      1.00      1899
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 8/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9497 - loss: 0.1177 - val_accuracy: 0.9997 - val_loss: 0.0023
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0066 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0051 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0048 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0048 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0046 - val_accuracy: 0.9997 - val_loss: 0.0020
# Fold 8 - Train Loss: 0.0047, Train Acc: 0.9993
# Fold 8 - Val Loss: 0.0020, Val Acc: 0.9997
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1907
#            1       1.00      1.00      1.00      1868
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 9/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9235 - loss: 0.1955 - val_accuracy: 0.9995 - val_loss: 0.0033
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 92ms/step - accuracy: 0.9988 - loss: 0.0097 - val_accuracy: 0.9995 - val_loss: 0.0032
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9989 - loss: 0.0080 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0075 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0073 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0072 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0071 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0072 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0071 - val_accuracy: 0.9995 - val_loss: 0.0032
# Fold 9 - Train Loss: 0.0051, Train Acc: 0.9993
# Fold 9 - Val Loss: 0.0031, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1930
#            1       1.00      1.00      1.00      1845
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 10/10 (BorderlineSMOTE)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9361 - loss: 0.1526 - val_accuracy: 0.9992 - val_loss: 0.0062
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0080 - val_accuracy: 0.9992 - val_loss: 0.0061
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0066 - val_accuracy: 0.9992 - val_loss: 0.0060
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9992 - val_loss: 0.0061
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0063 - val_accuracy: 0.9992 - val_loss: 0.0060
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9992 - val_loss: 0.0060
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0055 - val_accuracy: 0.9992 - val_loss: 0.0062
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0051 - val_accuracy: 0.9992 - val_loss: 0.0061
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0055 - val_accuracy: 0.9992 - val_loss: 0.0062
# Fold 10 - Train Loss: 0.0047, Train Acc: 0.9994
# Fold 10 - Val Loss: 0.0060, Val Acc: 0.9992
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1873
#            1       1.00      1.00      1.00      1902
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------

# %%
print(f"Mean Training Accuracy: {np.mean(train_accuracies):.4f} (Std: {np.std(train_accuracies):.4f})")
print(f"Mean Training Loss: {np.mean(train_losses):.4f} (Std: {np.std(train_losses):.4f})")
print(f"Mean Validation Accuracy: {np.mean(val_accuracies):.4f} (Std: {np.std(val_accuracies):.4f})")
print(f"Mean Validation Loss: {np.mean(val_losses):.4f} (Std: {np.std(val_losses):.4f})")
# Out:
# Mean Training Accuracy: 0.9993 (Std: 0.0000)
# Mean Training Loss: 0.0047 (Std: 0.0002)
# Mean Validation Accuracy: 0.9993 (Std: 0.0004)
# Mean Validation Loss: 0.0052 (Std: 0.0030)

# %%
if classification_reports_list:
    avg_report_borderline = {
        '0': { # Menggunakan '0' dan '1' (string) sesuai output dict classification_report
            'precision': np.mean([r['0']['precision'] for r in classification_reports_list if '0' in r]),
            'recall': np.mean([r['0']['recall'] for r in classification_reports_list if '0' in r]),
            'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports_list if '0' in r]),
            'support': np.sum([r['0']['support'] for r in classification_reports_list if '0' in r])
        },
        '1': { # Menggunakan '0' dan '1' (string)
            'precision': np.mean([r['1']['precision'] for r in classification_reports_list if '1' in r]),
            'recall': np.mean([r['1']['recall'] for r in classification_reports_list if '1' in r]),
            'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports_list if '1' in r]),
            'support': np.sum([r['1']['support'] for r in classification_reports_list if '1' in r])
        },
        'accuracy': np.mean([r['accuracy'] for r in classification_reports_list if 'accuracy' in r]),
        'macro avg': {
            'precision': np.mean([r['macro avg']['precision'] for r in classification_reports_list if 'macro avg' in r]),
            'recall': np.mean([r['macro avg']['recall'] for r in classification_reports_list if 'macro avg' in r]),
            'f1-score': np.mean([r['macro avg']['f1-score'] for r in classification_reports_list if 'macro avg' in r]),
        },
        'weighted avg': {
            'precision': np.mean([r['weighted avg']['precision'] for r in classification_reports_list if 'weighted avg' in r]),
            'recall': np.mean([r['weighted avg']['recall'] for r in classification_reports_list if 'weighted avg' in r]),
            'f1-score': np.mean([r['weighted avg']['f1-score'] for r in classification_reports_list if 'weighted avg' in r]),
        }
    }

    # Print the aggregated classification report
    print("Average Classification Report across all folds:")
    import json
    print(json.dumps(avg_report_borderline, indent=2))
else:
    print("No classification reports were generated.")
# Out:
# Average Classification Report across all folds:
# {
#   "0": {
#     "precision": 1.0,
#     "recall": 0.998564200028803,
#     "f1-score": 0.9992814235588131,
#     "support": 18875.0
#   },
#   "1": {
#     "precision": 0.9985769591063903,
#     "recall": 1.0,
#     "f1-score": 0.999287823509691,
#     "support": 18875.0
#   },
#   "accuracy": 0.9992847682119204,
#   "macro avg": {
#     "precision": 0.9992884795531951,
#     "recall": 0.9992821000144015,
#     "f1-score": 0.9992846235342521
#   },
#   "weighted avg": {
#     "precision": 0.9992860900278954,
#     "recall": 0.9992847682119204,
#     "f1-score": 0.9992847630992332
#   }
# }

# %%
import csv

csv_file = 'metrics_CNN_IndoBERT_BorderlineSMOTE.csv'
headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']
all_metrics = []
num_epochs_ran = len(history_borderline.history['loss'])

for epoch in range(num_epochs_ran):
    train_loss = history_borderline.history['loss'][epoch]
    train_accuracy = history_borderline.history['accuracy'][epoch]
    val_loss = history_borderline.history['val_loss'][epoch]
    val_accuracy = history_borderline.history['val_accuracy'][epoch]
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(headers)
    writer.writerows(all_metrics)
print(f"Metrics saved to {csv_file}")
# Out:
# Metrics saved to metrics_CNN_IndoBERT_BorderlineSMOTE.csv

# %% [markdown]
# ####Testing

# %%
 evaluation_test1_border = temp_model_border.evaluate(
    [x_test_padded1, non_static_logits_test1],
    y_test1,
    batch_size=128
)
accuracy_test1_border = evaluation_test1_border[1]

print(f"Test Set 1 Evaluation Results (BorderlineSMOTE):")
print(f"Loss: {evaluation_test1_border[0]:.4f}, Accuracy: {accuracy_test1_border:.4f}")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.9912 - loss: 0.0428
# Test Set 1 Evaluation Results (BorderlineSMOTE):
# Loss: 0.0464, Accuracy: 0.9900

# %%
# Classification Report for BorderlineSMOTE Test Set
y_pred_border = (temp_model_border.predict([x_test_padded1, non_static_logits_test1]) > 0.5).astype("int32").flatten()
print("\nClassification Report for BorderlineSMOTE Test Set:")
print(classification_report(y_test1, y_pred_border))
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
#
# Classification Report for BorderlineSMOTE Test Set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2097
#            1       0.89      0.89      0.89       104
#
#     accuracy                           0.99      2201
#    macro avg       0.94      0.94      0.94      2201
# weighted avg       0.99      0.99      0.99      2201

# %%
def show_confusion_matrix(confusion_matrix):
        hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
        hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
        hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')

print("Confusion Matrix for BorderlineSMOTE Test Set:")
cm_border = confusion_matrix(y_test1, y_pred_border)
show_confusion_matrix(cm_border)
plt.show()
# Out:
# Confusion Matrix for BorderlineSMOTE Test Set:

# %% [markdown]
# ###CNN + IndoBERT KMeansSMOTE

# %%
from tensorflow.keras import backend as K
K.clear_session()
gc.collect()
# Out:
# 0

# %%
sample_fraction = 0.3
sample_size = int(len(y_res_kmeans) * sample_fraction)

print(f"Total data KMeansSMOTE: {len(y_res_kmeans)}. Mengambil {sample_size} data untuk simple fit.")
# Out:
# Total data KMeansSMOTE: 37750. Mengambil 11325 data untuk simple fit.

# %%
indices = np.random.permutation(len(y_res_kmeans))
sample_indices = indices[:sample_size]

x_sample_pad = x_res_pad_kmeans[sample_indices]
x_sample_log = x_res_log_kmeans[sample_indices]
y_sample = y_res_kmeans[sample_indices]

print(f"Running simple fit on a sample of {sample_size} data points")
# Out:
# Running simple fit on a sample of 11325 data points

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
temp_model_kmeans = create_multichannel_model()
history_kmeans = temp_model_kmeans.fit(
    [x_sample_pad, x_sample_log],
    y_sample,
    batch_size=128,
    epochs=epochs,
    validation_split=0.1,
    callbacks=[early_stopping_keras],
)
# Out:
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.8375 - loss: 0.3804 - val_accuracy: 0.9982 - val_loss: 0.0106
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - accuracy: 0.9968 - loss: 0.0188 - val_accuracy: 0.9991 - val_loss: 0.0061
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.9994 - loss: 0.0092 - val_accuracy: 0.9991 - val_loss: 0.0065
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.9994 - loss: 0.0065 - val_accuracy: 0.9991 - val_loss: 0.0070
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.9996 - loss: 0.0052 - val_accuracy: 0.9991 - val_loss: 0.0076

# %% [markdown]
# ####Cross-Validation Train

# %%
# KFold
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
x_train_np_padded = np.array(x_res_pad_kmeans)
x_train_np_logits = np.array(x_res_log_kmeans)
y_train_np = np.array(y_res_kmeans)

train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []
classification_reports_list = []

# %%
fold = 0
for train_indices, val_indices in kf.split(x_train_np_padded):
    fold += 1
    print(f"Training fold {fold}/{num_folds} (KMeansSMOTE)")
    model_fold = create_multichannel_model()

    x_train_fold_padded = x_train_np_padded[train_indices]
    x_train_fold_logits = x_train_np_logits[train_indices]
    y_train_fold = y_train_np[train_indices]
    x_val_fold_padded = x_train_np_padded[val_indices]
    x_val_fold_logits = x_train_np_logits[val_indices]
    y_val_fold = y_train_np[val_indices]

    model_fold.fit(
        [x_train_fold_padded, x_train_fold_logits], y_train_fold,
        batch_size=128,
        epochs=epochs,
        validation_data=([x_val_fold_padded, x_val_fold_logits], y_val_fold),
        callbacks=[early_stopping_keras],
        verbose=1
    )

    train_loss, train_accuracy = model_fold.evaluate([x_train_fold_padded, x_train_fold_logits], y_train_fold, verbose=0)
    val_loss, val_accuracy = model_fold.evaluate([x_val_fold_padded, x_val_fold_logits], y_val_fold, verbose=0)

    print(f"Fold {fold} - Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Fold {fold} - Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")

    train_accuracies.append(train_accuracy); val_accuracies.append(val_accuracy)
    train_losses.append(train_loss); val_losses.append(val_loss)

    y_pred = (model_fold.predict([x_val_fold_padded, x_val_fold_logits]) > 0.5).astype("int32").flatten()
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports_list.append(report)
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)

    del model_fold
    gc.collect()
# Out:
# Training fold 1/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9350 - loss: 0.1585 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9988 - loss: 0.0089 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0077 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0070 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0060 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0064 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0056 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0059 - val_accuracy: 0.9995 - val_loss: 0.0037
# Fold 1 - Train Loss: 0.0044, Train Acc: 0.9994
# Fold 1 - Val Loss: 0.0037, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1884
#            1       1.00      1.00      1.00      1891
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 2/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9443 - loss: 0.1398 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0072 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0062 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0059 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0050 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0048 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0052 - val_accuracy: 0.9995 - val_loss: 0.0036
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0052 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9995 - val_loss: 0.0036
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0050 - val_accuracy: 0.9995 - val_loss: 0.0036
# Fold 2 - Train Loss: 0.0044, Train Acc: 0.9994
# Fold 2 - Val Loss: 0.0036, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1895
#            1       1.00      1.00      1.00      1880
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 3/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9585 - loss: 0.1103 - val_accuracy: 0.9989 - val_loss: 0.0077
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0067 - val_accuracy: 0.9989 - val_loss: 0.0082
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0055 - val_accuracy: 0.9989 - val_loss: 0.0085
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0054 - val_accuracy: 0.9989 - val_loss: 0.0089
# Fold 3 - Train Loss: 0.0049, Train Acc: 0.9993
# Fold 3 - Val Loss: 0.0077, Val Acc: 0.9989
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1862
#            1       1.00      1.00      1.00      1913
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 4/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9472 - loss: 0.1338 - val_accuracy: 0.9995 - val_loss: 0.0042
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0082 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0071 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0055 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0058 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0051 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0054 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9995 - val_loss: 0.0039
# Fold 4 - Train Loss: 0.0047, Train Acc: 0.9994
# Fold 4 - Val Loss: 0.0039, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1933
#            1       1.00      1.00      1.00      1842
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 5/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9195 - loss: 0.1908 - val_accuracy: 0.9997 - val_loss: 0.0024
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9987 - loss: 0.0093 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0073 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9989 - loss: 0.0073 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0062 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0064 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0065 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0067 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0067 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0062 - val_accuracy: 0.9997 - val_loss: 0.0020
# Fold 5 - Train Loss: 0.0047, Train Acc: 0.9993
# Fold 5 - Val Loss: 0.0020, Val Acc: 0.9997
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1864
#            1       1.00      1.00      1.00      1911
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 6/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9368 - loss: 0.1537 - val_accuracy: 0.9989 - val_loss: 0.0077
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0073 - val_accuracy: 0.9989 - val_loss: 0.0076
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9989 - val_loss: 0.0074
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.9989 - val_loss: 0.0074
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0048 - val_accuracy: 0.9989 - val_loss: 0.0073
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9989 - val_loss: 0.0073
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0046 - val_accuracy: 0.9989 - val_loss: 0.0072
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0043 - val_accuracy: 0.9989 - val_loss: 0.0074
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9995 - loss: 0.0042 - val_accuracy: 0.9989 - val_loss: 0.0076
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9995 - loss: 0.0038 - val_accuracy: 0.9989 - val_loss: 0.0078
# Fold 6 - Train Loss: 0.0041, Train Acc: 0.9994
# Fold 6 - Val Loss: 0.0072, Val Acc: 0.9989
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1851
#            1       1.00      1.00      1.00      1924
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 7/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9107 - loss: 0.2210 - val_accuracy: 0.9984 - val_loss: 0.0125
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 92ms/step - accuracy: 0.9989 - loss: 0.0080 - val_accuracy: 0.9984 - val_loss: 0.0117
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9984 - val_loss: 0.0116
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0055 - val_accuracy: 0.9984 - val_loss: 0.0118
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0050 - val_accuracy: 0.9984 - val_loss: 0.0119
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0049 - val_accuracy: 0.9984 - val_loss: 0.0123
# Fold 7 - Train Loss: 0.0042, Train Acc: 0.9994
# Fold 7 - Val Loss: 0.0116, Val Acc: 0.9984
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1876
#            1       1.00      1.00      1.00      1899
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 8/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9265 - loss: 0.1760 - val_accuracy: 0.9997 - val_loss: 0.0024
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0080 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0061 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0052 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0052 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0048 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0045 - val_accuracy: 0.9997 - val_loss: 0.0021
# Fold 8 - Train Loss: 0.0047, Train Acc: 0.9993
# Fold 8 - Val Loss: 0.0020, Val Acc: 0.9997
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1907
#            1       1.00      1.00      1.00      1868
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 9/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9425 - loss: 0.1413 - val_accuracy: 0.9995 - val_loss: 0.0033
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 92ms/step - accuracy: 0.9986 - loss: 0.0104 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0077 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0073 - val_accuracy: 0.9995 - val_loss: 0.0032
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0077 - val_accuracy: 0.9995 - val_loss: 0.0032
# Fold 9 - Train Loss: 0.0055, Train Acc: 0.9993
# Fold 9 - Val Loss: 0.0031, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1930
#            1       1.00      1.00      1.00      1845
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 10/10 (KMeansSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9231 - loss: 0.1930 - val_accuracy: 0.9992 - val_loss: 0.0064
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 92ms/step - accuracy: 0.9989 - loss: 0.0087 - val_accuracy: 0.9992 - val_loss: 0.0061
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0071 - val_accuracy: 0.9992 - val_loss: 0.0059
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9992 - loss: 0.0054 - val_accuracy: 0.9992 - val_loss: 0.0061
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9992 - loss: 0.0056 - val_accuracy: 0.9992 - val_loss: 0.0059
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0055 - val_accuracy: 0.9992 - val_loss: 0.0060
# Fold 10 - Train Loss: 0.0048, Train Acc: 0.9993
# Fold 10 - Val Loss: 0.0059, Val Acc: 0.9992
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1873
#            1       1.00      1.00      1.00      1902
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------

# %%
print(f"Mean Training Accuracy: {np.mean(train_accuracies):.4f} (Std: {np.std(train_accuracies):.4f})")
print(f"Mean Training Loss: {np.mean(train_losses):.4f} (Std: {np.std(train_losses):.4f})")
print(f"Mean Validation Accuracy: {np.mean(val_accuracies):.4f} (Std: {np.std(val_accuracies):.4f})")
print(f"Mean Validation Loss: {np.mean(val_losses):.4f} (Std: {np.std(val_losses):.4f})")
# Out:
# Mean Training Accuracy: 0.9993 (Std: 0.0000)
# Mean Training Loss: 0.0046 (Std: 0.0004)
# Mean Validation Accuracy: 0.9993 (Std: 0.0004)
# Mean Validation Loss: 0.0051 (Std: 0.0029)

# %%
if classification_reports_list:
    avg_report_kmeans = {
        '0': { # Menggunakan '0' dan '1' (string) sesuai output dict classification_report
            'precision': np.mean([r['0']['precision'] for r in classification_reports_list if '0' in r]),
            'recall': np.mean([r['0']['recall'] for r in classification_reports_list if '0' in r]),
            'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports_list if '0' in r]),
            'support': np.sum([r['0']['support'] for r in classification_reports_list if '0' in r])
        },
        '1': { # Menggunakan '0' dan '1' (string)
            'precision': np.mean([r['1']['precision'] for r in classification_reports_list if '1' in r]),
            'recall': np.mean([r['1']['recall'] for r in classification_reports_list if '1' in r]),
            'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports_list if '1' in r]),
            'support': np.sum([r['1']['support'] for r in classification_reports_list if '1' in r])
        },
        'accuracy': np.mean([r['accuracy'] for r in classification_reports_list if 'accuracy' in r]),
        'macro avg': {
            'precision': np.mean([r['macro avg']['precision'] for r in classification_reports_list if 'macro avg' in r]),
            'recall': np.mean([r['macro avg']['recall'] for r in classification_reports_list if 'macro avg' in r]),
            'f1-score': np.mean([r['macro avg']['f1-score'] for r in classification_reports_list if 'macro avg' in r]),
        },
        'weighted avg': {
            'precision': np.mean([r['weighted avg']['precision'] for r in classification_reports_list if 'weighted avg' in r]),
            'recall': np.mean([r['weighted avg']['recall'] for r in classification_reports_list if 'weighted avg' in r]),
            'f1-score': np.mean([r['weighted avg']['f1-score'] for r in classification_reports_list if 'weighted avg' in r]),
        }
    }

    # Print the aggregated classification report
    print("Average Classification Report across all folds:")
    import json
    print(json.dumps(avg_report_kmeans, indent=2))
else:
    print("No classification reports were generated.")
# Out:
# Average Classification Report across all folds:
# {
#   "0": {
#     "precision": 1.0,
#     "recall": 0.998564200028803,
#     "f1-score": 0.9992814235588131,
#     "support": 18875.0
#   },
#   "1": {
#     "precision": 0.9985769591063903,
#     "recall": 1.0,
#     "f1-score": 0.999287823509691,
#     "support": 18875.0
#   },
#   "accuracy": 0.9992847682119204,
#   "macro avg": {
#     "precision": 0.9992884795531951,
#     "recall": 0.9992821000144015,
#     "f1-score": 0.9992846235342521
#   },
#   "weighted avg": {
#     "precision": 0.9992860900278954,
#     "recall": 0.9992847682119204,
#     "f1-score": 0.9992847630992332
#   }
# }

# %%
csv_file = 'metrics_CNN_IndoBERT_KMeansSMOTE.csv'
headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']
all_metrics = []
num_epochs_ran = len(history_kmeans.history['loss'])

for epoch in range(num_epochs_ran):
    train_loss = history_kmeans.history['loss'][epoch]
    train_accuracy = history_kmeans.history['accuracy'][epoch]
    val_loss = history_kmeans.history['val_loss'][epoch]
    val_accuracy = history_kmeans.history['val_accuracy'][epoch]
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(headers)
    writer.writerows(all_metrics)
print(f"Metrics saved to {csv_file}")
# Out:
# Metrics saved to metrics_CNN_IndoBERT_KMeansSMOTE.csv

# %% [markdown]
# ####Testing

# %%
 evaluation_test1_border = temp_model_kmeans.evaluate(
    [x_test_padded1, non_static_logits_test1],
    y_test1,
    batch_size=128
)
accuracy_test1_border = evaluation_test1_border[1]

print(f"Test Set 1 Evaluation Results (KMeansSMOTE):")
print(f"Loss: {evaluation_test1_border[0]:.4f}, Accuracy: {accuracy_test1_border:.4f}")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9914 - loss: 0.0328
# Test Set 1 Evaluation Results (KMeansSMOTE):
# Loss: 0.0372, Accuracy: 0.9905

# %%
# Classification Report for KMeansSMOTE Test Set
y_pred_kmeans = (temp_model_kmeans.predict([x_test_padded1, non_static_logits_test1]) > 0.5).astype("int32").flatten()
print("\nClassification Report for KMeansSMOTE Test Set:")
print(classification_report(y_test1, y_pred_kmeans))
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
#
# Classification Report for KMeansSMOTE Test Set:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2097
#            1       0.90      0.90      0.90       104
#
#     accuracy                           0.99      2201
#    macro avg       0.95      0.95      0.95      2201
# weighted avg       0.99      0.99      0.99      2201

# %%
print("\nConfusion Matrix for KMeansSMOTE Test Set:")
cm_kmeans = confusion_matrix(y_test1, y_pred_kmeans)
show_confusion_matrix(cm_kmeans)
plt.show()
# Out:
# Confusion Matrix for KMeansSMOTE Test Set:

# %% [markdown]
# ###CNN + IndoBERT SVMSMOTE

# %%
temp_model_svm = create_multichannel_model()
history_svm = temp_model_svm.fit(
    [x_res_pad_svm, x_res_log_svm],
    y_res_svm,
    batch_size=128,
    epochs=epochs,
    validation_split=0.1,
    callbacks=[early_stopping_keras],
)
gc.collect()
# Out:
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9543 - loss: 0.1162 - val_accuracy: 1.0000 - val_loss: 7.9214e-04
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 9.9102e-04
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 9.0256e-04
# 7271

# %% [markdown]
# ####Cross-Validation Train

# %%
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
x_train_np_padded = np.array(x_res_pad_svm)
x_train_np_logits = np.array(x_res_log_svm)
y_train_np = np.array(y_res_svm)

train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []
classification_reports_list = []

# %%
fold = 0
for train_indices, val_indices in kf.split(x_train_np_padded):
    fold += 1
    print(f"Training fold {fold}/{num_folds} (SVMSMOTE)")
    model_fold = create_multichannel_model()

    x_train_fold_padded = x_train_np_padded[train_indices]
    x_train_fold_logits = x_train_np_logits[train_indices]
    y_train_fold = y_train_np[train_indices]
    x_val_fold_padded = x_train_np_padded[val_indices]
    x_val_fold_logits = x_train_np_logits[val_indices]
    y_val_fold = y_train_np[val_indices]

    model_fold.fit(
        [x_train_fold_padded, x_train_fold_logits], y_train_fold,
        batch_size=128,
        epochs=epochs,
        validation_data=([x_val_fold_padded, x_val_fold_logits], y_val_fold),
        callbacks=[early_stopping_keras],
        verbose=1
    )

    train_loss, train_accuracy = model_fold.evaluate([x_train_fold_padded, x_train_fold_logits], y_train_fold, verbose=0)
    val_loss, val_accuracy = model_fold.evaluate([x_val_fold_padded, x_val_fold_logits], y_val_fold, verbose=0)

    print(f"Fold {fold} - Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Fold {fold} - Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")

    train_accuracies.append(train_accuracy); val_accuracies.append(val_accuracy)
    train_losses.append(train_loss); val_losses.append(val_loss)

    y_pred = (model_fold.predict([x_val_fold_padded, x_val_fold_logits]) > 0.5).astype("int32").flatten()
    report = classification_report(y_val_fold, y_pred, output_dict=True)
    classification_reports_list.append(report)
    print(classification_report(y_val_fold, y_pred))
    print("-" * 60)

    del model_fold
    gc.collect()
# Out:
# Training fold 1/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9279 - loss: 0.1762 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9987 - loss: 0.0096 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0075 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0074 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9992 - loss: 0.0057 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0061 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0056 - val_accuracy: 0.9995 - val_loss: 0.0037
# Fold 1 - Train Loss: 0.0046, Train Acc: 0.9993
# Fold 1 - Val Loss: 0.0037, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1884
#            1       1.00      1.00      1.00      1891
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 2/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9023 - loss: 0.2302 - val_accuracy: 0.9995 - val_loss: 0.0042
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0086 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0061 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0057 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9992 - loss: 0.0056 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0048 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0049 - val_accuracy: 0.9995 - val_loss: 0.0036
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9995 - val_loss: 0.0036
# Fold 2 - Train Loss: 0.0044, Train Acc: 0.9994
# Fold 2 - Val Loss: 0.0036, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1895
#            1       1.00      1.00      1.00      1880
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 3/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9352 - loss: 0.1651 - val_accuracy: 0.9989 - val_loss: 0.0078
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0077 - val_accuracy: 0.9989 - val_loss: 0.0082
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0057 - val_accuracy: 0.9989 - val_loss: 0.0086
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0051 - val_accuracy: 0.9989 - val_loss: 0.0089
# Fold 3 - Train Loss: 0.0052, Train Acc: 0.9993
# Fold 3 - Val Loss: 0.0078, Val Acc: 0.9989
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1862
#            1       1.00      1.00      1.00      1913
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 4/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9311 - loss: 0.1700 - val_accuracy: 0.9995 - val_loss: 0.0043
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9989 - loss: 0.0086 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0067 - val_accuracy: 0.9995 - val_loss: 0.0040
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0061 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0056 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0060 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9995 - val_loss: 0.0039
# Fold 4 - Train Loss: 0.0046, Train Acc: 0.9993
# Fold 4 - Val Loss: 0.0038, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1933
#            1       1.00      1.00      1.00      1842
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 5/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.8942 - loss: 0.2494 - val_accuracy: 0.9997 - val_loss: 0.0024
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9987 - loss: 0.0102 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0081 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9989 - loss: 0.0077 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0069 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0068 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0065 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0061 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0065 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0061 - val_accuracy: 0.9997 - val_loss: 0.0020
# Fold 5 - Train Loss: 0.0047, Train Acc: 0.9993
# Fold 5 - Val Loss: 0.0020, Val Acc: 0.9997
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1864
#            1       1.00      1.00      1.00      1911
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 6/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9441 - loss: 0.1360 - val_accuracy: 0.9989 - val_loss: 0.0079
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0065 - val_accuracy: 0.9989 - val_loss: 0.0079
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0051 - val_accuracy: 0.9989 - val_loss: 0.0078
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0049 - val_accuracy: 0.9989 - val_loss: 0.0074
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.9989 - val_loss: 0.0076
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9995 - loss: 0.0043 - val_accuracy: 0.9989 - val_loss: 0.0075
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0042 - val_accuracy: 0.9989 - val_loss: 0.0074
# Fold 6 - Train Loss: 0.0043, Train Acc: 0.9994
# Fold 6 - Val Loss: 0.0074, Val Acc: 0.9989
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1851
#            1       1.00      1.00      1.00      1924
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 7/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9410 - loss: 0.1507 - val_accuracy: 0.9984 - val_loss: 0.0119
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0072 - val_accuracy: 0.9984 - val_loss: 0.0122
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9993 - loss: 0.0058 - val_accuracy: 0.9984 - val_loss: 0.0119
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0049 - val_accuracy: 0.9984 - val_loss: 0.0121
# Fold 7 - Train Loss: 0.0046, Train Acc: 0.9994
# Fold 7 - Val Loss: 0.0119, Val Acc: 0.9984
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1876
#            1       1.00      1.00      1.00      1899
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 8/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.8659 - loss: 0.3745 - val_accuracy: 0.9997 - val_loss: 0.0028
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9987 - loss: 0.0093 - val_accuracy: 0.9997 - val_loss: 0.0022
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0061 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0053 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9994 - loss: 0.0050 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 8/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 9/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0049 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 10/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0051 - val_accuracy: 0.9997 - val_loss: 0.0020
# Fold 8 - Train Loss: 0.0047, Train Acc: 0.9993
# Fold 8 - Val Loss: 0.0020, Val Acc: 0.9997
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1907
#            1       1.00      1.00      1.00      1868
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 9/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 103ms/step - accuracy: 0.9436 - loss: 0.1420 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0101 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0088 - val_accuracy: 0.9995 - val_loss: 0.0032
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9990 - loss: 0.0078 - val_accuracy: 0.9995 - val_loss: 0.0030
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0070 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0075 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.9991 - loss: 0.0071 - val_accuracy: 0.9995 - val_loss: 0.0032
# Fold 9 - Train Loss: 0.0051, Train Acc: 0.9993
# Fold 9 - Val Loss: 0.0030, Val Acc: 0.9995
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1930
#            1       1.00      1.00      1.00      1845
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------
# Training fold 10/10 (SVMSMOTE)
# Epoch 1/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 104ms/step - accuracy: 0.9283 - loss: 0.1683 - val_accuracy: 0.9992 - val_loss: 0.0063
# Epoch 2/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 92ms/step - accuracy: 0.9989 - loss: 0.0082 - val_accuracy: 0.9992 - val_loss: 0.0059
# Epoch 3/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9991 - loss: 0.0074 - val_accuracy: 0.9992 - val_loss: 0.0060
# Epoch 4/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9992 - loss: 0.0059 - val_accuracy: 0.9992 - val_loss: 0.0058
# Epoch 5/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0051 - val_accuracy: 0.9992 - val_loss: 0.0062
# Epoch 6/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9992 - val_loss: 0.0060
# Epoch 7/10
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9992 - val_loss: 0.0060
# Fold 10 - Train Loss: 0.0047, Train Acc: 0.9993
# Fold 10 - Val Loss: 0.0058, Val Acc: 0.9992
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1873
#            1       1.00      1.00      1.00      1902
#
#     accuracy                           1.00      3775
#    macro avg       1.00      1.00      1.00      3775
# weighted avg       1.00      1.00      1.00      3775
#
# ------------------------------------------------------------

# %%
print(f"Mean Training Accuracy: {np.mean(train_accuracies):.4f} (Std: {np.std(train_accuracies):.4f})")
print(f"Mean Training Loss: {np.mean(train_losses):.4f} (Std: {np.std(train_losses):.4f})")
print(f"Mean Validation Accuracy: {np.mean(val_accuracies):.4f} (Std: {np.std(val_accuracies):.4f})")
print(f"Mean Validation Loss: {np.mean(val_losses):.4f} (Std: {np.std(val_losses):.4f})")
# Out:
# Mean Training Accuracy: 0.9993 (Std: 0.0000)
# Mean Training Loss: 0.0047 (Std: 0.0003)
# Mean Validation Accuracy: 0.9993 (Std: 0.0004)
# Mean Validation Loss: 0.0051 (Std: 0.0030)

# %%
if classification_reports_list:
    avg_report_svm = {
        '0': { # Menggunakan '0' dan '1' (string) sesuai output dict classification_report
            'precision': np.mean([r['0']['precision'] for r in classification_reports_list if '0' in r]),
            'recall': np.mean([r['0']['recall'] for r in classification_reports_list if '0' in r]),
            'f1-score': np.mean([r['0']['f1-score'] for r in classification_reports_list if '0' in r]),
            'support': np.sum([r['0']['support'] for r in classification_reports_list if '0' in r])
        },
        '1': { # Menggunakan '0' dan '1' (string)
            'precision': np.mean([r['1']['precision'] for r in classification_reports_list if '1' in r]),
            'recall': np.mean([r['1']['recall'] for r in classification_reports_list if '1' in r]),
            'f1-score': np.mean([r['1']['f1-score'] for r in classification_reports_list if '1' in r]),
            'support': np.sum([r['1']['support'] for r in classification_reports_list if '1' in r])
        },
        'accuracy': np.mean([r['accuracy'] for r in classification_reports_list if 'accuracy' in r]),
        'macro avg': {
            'precision': np.mean([r['macro avg']['precision'] for r in classification_reports_list if 'macro avg' in r]),
            'recall': np.mean([r['macro avg']['recall'] for r in classification_reports_list if 'macro avg' in r]),
            'f1-score': np.mean([r['macro avg']['f1-score'] for r in classification_reports_list if 'macro avg' in r]),
        },
        'weighted avg': {
            'precision': np.mean([r['weighted avg']['precision'] for r in classification_reports_list if 'weighted avg' in r]),
            'recall': np.mean([r['weighted avg']['recall'] for r in classification_reports_list if 'weighted avg' in r]),
            'f1-score': np.mean([r['weighted avg']['f1-score'] for r in classification_reports_list if 'weighted avg' in r]),
        }
    }

    # Print the aggregated classification report
    print("Average Classification Report across all folds:")
    import json
    print(json.dumps(avg_report_svm, indent=2))
else:
    print("No classification reports were generated.")
# Out:
# Average Classification Report across all folds:
# {
#   "0": {
#     "precision": 1.0,
#     "recall": 0.998564200028803,
#     "f1-score": 0.9992814235588131,
#     "support": 18875.0
#   },
#   "1": {
#     "precision": 0.9985769591063903,
#     "recall": 1.0,
#     "f1-score": 0.999287823509691,
#     "support": 18875.0
#   },
#   "accuracy": 0.9992847682119204,
#   "macro avg": {
#     "precision": 0.9992884795531951,
#     "recall": 0.9992821000144015,
#     "f1-score": 0.9992846235342521
#   },
#   "weighted avg": {
#     "precision": 0.9992860900278954,
#     "recall": 0.9992847682119204,
#     "f1-score": 0.9992847630992332
#   }
# }

# %%
csv_file = 'metrics_CNN_IndoBERT_SVMSMOTE.csv'
headers = ['epoch', 'train_loss', 'train_accuracy', 'val_loss', 'val_accuracy']
all_metrics = []
num_epochs_ran = len(history_svm.history['loss'])

for epoch in range(num_epochs_ran):
    train_loss = history_svm.history['loss'][epoch]
    train_accuracy = history_svm.history['accuracy'][epoch]
    val_loss = history_svm.history['val_loss'][epoch]
    val_accuracy = history_svm.history['val_accuracy'][epoch]
    all_metrics.append([epoch + 1, train_loss, train_accuracy, val_loss, val_accuracy])

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(headers)
    writer.writerows(all_metrics)
print(f"Metrics saved to {csv_file}")
# Out:
# Metrics saved to metrics_CNN_IndoBERT_SVMSMOTE.csv

# %% [markdown]
# ####Testing

# %%
 evaluation_test1_border = temp_model_svm.evaluate(
    [x_test_padded1, non_static_logits_test1],
    y_test1,
    batch_size=128
)
accuracy_test1_border = evaluation_test1_border[1]

print(f"Test Set 1 Evaluation Results (SVMSMOTE):")
print(f"Loss: {evaluation_test1_border[0]:.4f}, Accuracy: {accuracy_test1_border:.4f}")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9913 - loss: 0.0407
# Test Set 1 Evaluation Results (SVMSMOTE):
# Loss: 0.0446, Accuracy: 0.9905

# %%
# Classification Report for SVMSMOTE Test Set
y_pred_svm = (temp_model_svm.predict([x_test_padded1, non_static_logits_test1]) > 0.5).astype("int32").flatten()
print("\nClassification Report for SVMSMOTE Test Set:")
print(classification_report(y_test1, y_pred_svm))
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
#
# Classification Report for SVMSMOTE Test Set:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2097
#            1       0.90      0.89      0.90       104
#
#     accuracy                           0.99      2201
#    macro avg       0.95      0.94      0.95      2201
# weighted avg       0.99      0.99      0.99      2201

# %%
print("\nConfusion Matrix for SVMSMOTE Test Set:")
cm_svm = confusion_matrix(y_test1, y_pred_svm)
show_confusion_matrix(cm_svm)
plt.show()
# Out:
# Confusion Matrix for SVMSMOTE Test Set:

# %% [markdown]
# ##Evaluation

# %% [markdown]
# ###BorderlineSMOTE

# %%
# Plot Loss
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
train_loss = history_borderline.history['loss']
val_loss = history_borderline.history['val_loss']
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss CNN+IndoBERT (BorderlineSMOTE)')
plt.legend()

# %%
# Plot Accuracy
# plt.subplot(1, 2, 2)
train_accuracy = history_borderline.history['accuracy']
val_accuracy = history_borderline.history['val_accuracy']
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy CNN+IndoBERT (BorderlineSMOTE)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ###KMeansSMOTE

# %%
# Plot Loss
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
train_loss = history_kmeans.history['loss']
val_loss = history_kmeans.history['val_loss']
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss CNN+IndoBERT (KMeansSMOTE)')
plt.legend()

# %%
# Plot Accuracy
# plt.subplot(1, 2, 2)
train_accuracy = history_kmeans.history['accuracy']
val_accuracy = history_kmeans.history['val_accuracy']
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy CNN+IndoBERT (KMeansSMOTE)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ###SVMSMOTE

# %%
# Plot Loss
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
train_loss = history_svm.history['loss']
val_loss = history_svm.history['val_loss']
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss CNN+IndoBERT (SVMSMOTE)')
plt.legend()

# %%
# Plot Accuracy
# plt.subplot(1, 2, 2)
train_accuracy = history_svm.history['accuracy']
val_accuracy = history_svm.history['val_accuracy']
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy CNN+IndoBERT (SVMSMOTE)')
plt.legend()
plt.tight_layout()
plt.show()
